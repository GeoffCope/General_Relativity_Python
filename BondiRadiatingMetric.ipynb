# %% [markdown]
# # Bondi's Radiating Metric
# ##  Geoff Cope
# ##  University of Utah
# ##  December 22, 2021

# %% [markdown]
# This metric is taken from D'Inverno Introducing Einstein's Relativity First Edition Page 295.  The corresponding output for the Christoffel Symbols and Ricci Tensor are listed on Page 369 in the answers section.  The Christoffel symbols seem to compute just fine, however the Ricci Tensor is taking enitirely too long.  Will speed this up at a later date.  Also, trying to figure out how to typeset dtheta and dphi.  Using: from sympy.diffgeom.rn import * and then R2.dtheta will typset a dtheta, but haven't figured out a dphi yet.  As a workaround we use dx and dy in their place although x and y have nothing to do with the metric.

# %% [markdown]
# https://profmcruz.files.wordpress.com/2018/02/livro-introducing-einsteins-relativity-dinverno.pdf

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
u,r,theta,phi,du,dr,dtheta,dphi,dx,dy = symbols( 'u r theta phi du dr dtheta dphi dx dy' )

# %%
gamma = symbols('gamma')
beta = symbols('beta')

# %%
variables = Matrix( [u,r,theta,phi])
variables
# Out:
# ⎡u⎤
# ⎢ ⎥
# ⎢r⎥
# ⎢ ⎥
# ⎢θ⎥
# ⎢ ⎥
# ⎣φ⎦

# %%
differentials = Matrix( [du,dr,dx,dy])
differentials
# Out:
# ⎡du⎤
# ⎢  ⎥
# ⎢dr⎥
# ⎢  ⎥
# ⎢dx⎥
# ⎢  ⎥
# ⎣dy⎦

# %%
V = Function('V')(u,r,theta)
V
# Out:
# V(u, r, θ)

# %%
U = Function('U')(u,r,theta)
U
# Out:
# U(u, r, θ)

# %%
beta = Function('beta')(u,r,theta)
beta
# Out:
# β(u, r, θ)

# %%
gamma = Function('gamma')(u,r,theta)
gamma
# Out:
# γ(u, r, θ)

# %%
lineElement = expand(( (V/r)*exp(2*beta)-U**2 * r**2 * exp(2*gamma))*du**2 + 2*exp(2*beta)*du*dr + 2* U* r**2 * exp(2*gamma)* du * dx - r**2 * (exp(2*gamma) * dx**2 + exp(-2*gamma) * sin(theta)**2 * dy**2))
lineElement
# Out:
#                                                              2             2⋅β(u, r, θ)
#          2⋅β(u, r, θ)     2  2  2           2⋅γ(u, r, θ)   du ⋅V(u, r, θ)⋅ℯ
# 2⋅dr⋅du⋅ℯ             - du ⋅r ⋅U (u, r, θ)⋅ℯ             + ──────────────────────────── + 2⋅
#                                                                         r
#
#
#        2             2⋅γ(u, r, θ)     2  2  2⋅γ(u, r, θ)     2  2  -2⋅γ(u, r, θ)    2
# du⋅dx⋅r ⋅U(u, r, θ)⋅ℯ             - dx ⋅r ⋅ℯ             - dy ⋅r ⋅ℯ             ⋅sin (θ)

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡                                             2⋅β(u, r, θ)
# ⎢   2  2           2⋅γ(u, r, θ)   V(u, r, θ)⋅ℯ               2⋅β(u, r, θ)   2             2⋅
# ⎢- r ⋅U (u, r, θ)⋅ℯ             + ────────────────────────  ℯ              r ⋅U(u, r, θ)⋅ℯ
# ⎢                                            r
# ⎢
# ⎢                       2⋅β(u, r, θ)
# ⎢                      ℯ                                          0                     0
# ⎢
# ⎢                2             2⋅γ(u, r, θ)                                       2  2⋅γ(u,
# ⎢               r ⋅U(u, r, θ)⋅ℯ                                   0             -r ⋅ℯ
# ⎢
# ⎢
# ⎣                            0                                    0                     0
#
#                                       ⎤
# γ(u, r, θ)                            ⎥
#                         0             ⎥
#                                       ⎥
#                                       ⎥
#                                       ⎥
#                         0             ⎥
#                                       ⎥
# r, θ)                                 ⎥
#                         0             ⎥
#                                       ⎥
#               2  -2⋅γ(u, r, θ)    2   ⎥
#             -r ⋅ℯ             ⋅sin (θ)⎦

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡                                             2⋅β(u, r, θ)
# ⎢   2  2           2⋅γ(u, r, θ)   V(u, r, θ)⋅ℯ               2⋅β(u, r, θ)   2             2⋅
# ⎢- r ⋅U (u, r, θ)⋅ℯ             + ────────────────────────  ℯ              r ⋅U(u, r, θ)⋅ℯ
# ⎢                                            r
# ⎢
# ⎢                       2⋅β(u, r, θ)
# ⎢                      ℯ                                          0                     0
# ⎢
# ⎢                2             2⋅γ(u, r, θ)                                       2  2⋅γ(u,
# ⎢               r ⋅U(u, r, θ)⋅ℯ                                   0             -r ⋅ℯ
# ⎢
# ⎢
# ⎣                            0                                    0                     0
#
#                                       ⎤
# γ(u, r, θ)                            ⎥
#                         0             ⎥
#                                       ⎥
#                                       ⎥
#                                       ⎥
#                         0             ⎥
#                                       ⎥
# r, θ)                                 ⎥
#                         0             ⎥
#                                       ⎥
#               2  -2⋅γ(u, r, θ)    2   ⎥
#             -r ⋅ℯ             ⋅sin (θ)⎦

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("u r theta phi")
u,r,theta,phi = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
ch.tensor()
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢⎡⎛
# ⎢⎢⎜
# ⎢⎢⎜   2  2           2⋅γ(u, r, θ) ∂                   2             2⋅γ(u, r, θ) ∂
# ⎢⎢⎜2⋅r ⋅U (u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) + 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(U(u, r,
# ⎢⎢⎜                               ∂r                                             ∂r
# ⎢⎢⎝
# ⎢⎢──────────────────────────────────────────────────────────────────────────────────────────
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                         ⎛     2             2⋅γ(u, r, θ)
# ⎢⎢                                                         ⎜- 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅
# ⎢⎢                                                         ⎝
# ⎢⎢                                                         ─────────────────────────────────
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎣
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#
#
#
#                                                                                      2⋅β(u,
#                                                                        2⋅V(u, r, θ)⋅ℯ
#            2           2⋅γ(u, r, θ)      2⋅β(u, r, θ) ∂
# θ)) + 2⋅r⋅U (u, r, θ)⋅ℯ             + 4⋅ℯ            ⋅──(β(u, r, θ)) - ─────────────────────
#                                                       ∂u                                   r
#
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                2
#
#                                                0
#
# ∂                 2  2⋅γ(u, r, θ) ∂                                2⋅γ(u, r, θ)      2⋅β(u,
# ──(γ(u, r, θ)) - r ⋅ℯ            ⋅──(U(u, r, θ)) - 2⋅r⋅U(u, r, θ)⋅ℯ             + 2⋅ℯ
# ∂r                                ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                2
#
#
#
#
#                                                0
#
#
#
#
#
#
#
#
#
#
#
# r, θ) ∂                 2⋅β(u, r, θ) ∂                                        ⎞
#      ⋅──(β(u, r, θ))   ℯ            ⋅──(V(u, r, θ))               2⋅β(u, r, θ)⎟
#       ∂r                             ∂r               V(u, r, θ)⋅ℯ            ⎟  -2⋅β(u, r,
# ──────────────────── - ──────────────────────────── + ────────────────────────⎟⋅ℯ
#                                     r                             2           ⎟
#                                                                  r            ⎠
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
# r, θ) ∂             ⎞  -2⋅β(u, r, θ)
#      ⋅──(β(u, r, θ))⎟⋅ℯ
#       ∂θ            ⎠
# ────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# θ)
#        ⎛     2             2⋅γ(u, r, θ) ∂                 2  2⋅γ(u, r, θ) ∂
#        ⎜- 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) - r ⋅ℯ            ⋅──(U(u, r, θ)) - 2
#        ⎝                                ∂r                                ∂r
# ──  0  ─────────────────────────────────────────────────────────────────────────────────────
#                                                                                        2
#
#     0                                                                                  0
#
#                                                     ⎛   2  2⋅γ(u, r, θ) ∂
#                                                     ⎜2⋅r ⋅ℯ            ⋅──(γ(u, r, θ)) + 2⋅r
#                                                     ⎝                   ∂r
#     0                                               ────────────────────────────────────────
#                                                                                       2
#
#
#
#
#     0                                                                                  0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                2⋅γ(u, r, θ)      2⋅β(u, r, θ) ∂             ⎞  -2⋅β(u, r, θ)
# ⋅r⋅U(u, r, θ)⋅ℯ             + 2⋅ℯ            ⋅──(β(u, r, θ))⎟⋅ℯ
#                                               ∂θ            ⎠
# ────────────────────────────────────────────────────────────────────────────
#
#
#
#
#   2⋅γ(u, r, θ)⎞  -2⋅β(u, r, θ)
# ⋅ℯ            ⎟⋅ℯ
#               ⎠
# ──────────────────────────────
#
#
#                                                                               ⎛     2  -2⋅γ(
#                                                                               ⎜- 2⋅r ⋅ℯ
#                                                                               ⎝
#                                                                               ──────────────
#
#
#
#
#
#
#
#                                                                                ⎡
#                                                                                ⎢⎛
#                                                                                ⎢⎜
#                                                                                ⎢⎜     2  2
#                                                                             ⎤  ⎢⎜- 2⋅r ⋅U (u
#                                                                             ⎥  ⎢⎝
#                                                                             ⎥  ⎢────────────
#                                                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                               0                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                               0                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                               0                                             ⎥  ⎢
#                                                                             ⎥  ⎢
#                                                                             ⎥  ⎢
# u, r, θ)    2    ∂                     -2⋅γ(u, r, θ)    2   ⎞  -2⋅β(u, r, θ)⎥  ⎢
#         ⋅sin (θ)⋅──(γ(u, r, θ)) + 2⋅r⋅ℯ             ⋅sin (θ)⎟⋅ℯ             ⎥  ⎢
#                  ∂r                                         ⎠               ⎥  ⎢
# ────────────────────────────────────────────────────────────────────────────⎥  ⎢
#                               2                                             ⎦  ⎢
#                                                                                ⎢
#                                                                                ⎢
#                                                                                ⎢
#                                                                                ⎢
#                                                                                ⎣
#
#
#
#                                                                                       2⋅V(u,
#          2⋅γ(u, r, θ) ∂                   2             2⋅γ(u, r, θ) ∂
# , r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) - 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(U(u, r, θ)) + ──────
#                       ∂u                                             ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         2⋅β(u, r, θ) ∂                 2⋅β(u, r, θ) ∂             ⎞                  ⎛
#  r, θ)⋅ℯ            ⋅──(β(u, r, θ))   ℯ            ⋅──(V(u, r, θ))⎟                  ⎜
#                      ∂u                             ∂u            ⎟  -2⋅β(u, r, θ)   ⎜   2
# ─────────────────────────────────── + ────────────────────────────⎟⋅ℯ                ⎜2⋅r ⋅U
#               r                                    r              ⎠                  ⎝
# ────────────────────────────────────────────────────────────────────────────────── + ───────
#
#
#
#
#
#                                                                  ⎛   2             2⋅γ(u, r,
#                                                                  ⎜2⋅r ⋅U(u, r, θ)⋅ℯ
#                                                                  ⎝
#                                                                  ───────────────────────────
#
#
#
#
#
#
#                                                                   2             -2⋅β(u, r, θ
#                                                                - r ⋅U(u, r, θ)⋅ℯ
#
#
#
#
#
#
#
#
#
#
#
# 2           2⋅γ(u, r, θ) ∂                   2             2⋅γ(u, r, θ) ∂
#  (u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) + 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(U(u, r, θ)) + 4⋅r
#                          ∂θ                                             ∂θ
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  θ) ∂                 2  2⋅γ(u, r, θ) ∂                                2⋅γ(u, r, θ)      2⋅β
#    ⋅──(γ(u, r, θ)) + r ⋅ℯ            ⋅──(U(u, r, θ)) + 2⋅r⋅U(u, r, θ)⋅ℯ             - 2⋅ℯ
#     ∂r                                ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                          2
#
#                                  ⎛
#                                  ⎜
#                                  ⎜     2  2           2⋅γ(u, r, θ) ∂                   2
#                                  ⎜- 2⋅r ⋅U (u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) - 2⋅r ⋅U(u
# )  2⋅γ(u, r, θ) ∂                ⎝                                 ∂θ
#  ⋅ℯ            ⋅──(γ(u, r, θ)) + ───────────────────────────────────────────────────────────
#                 ∂u
#
#
#
#
#
#
#
#
#
#                                                                                 2⋅V(u, r, θ)
# 2             2⋅γ(u, r, θ) ∂                   2  2⋅γ(u, r, θ) ∂
#  ⋅U(u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) + 2⋅r ⋅ℯ            ⋅──(U(u, r, θ)) - ────────────
#                            ∂u                                  ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                        2
#
#                                                       ⎛
#                                                       ⎜
#                                                       ⎜     2  2           2⋅γ(u, r, θ) ∂
# (u, r, θ) ∂             ⎞             -2⋅β(u, r, θ)   ⎜- 2⋅r ⋅U (u, r, θ)⋅ℯ            ⋅──(γ
#          ⋅──(β(u, r, θ))⎟⋅U(u, r, θ)⋅ℯ                ⎜                                 ∂r
#           ∂θ            ⎠                             ⎝
# ─────────────────────────────────────────────────── + ──────────────────────────────────────
#
#
#                                                      2⋅β(u, r, θ) ∂                 2⋅β(u, r
#                                        2⋅V(u, r, θ)⋅ℯ            ⋅──(β(u, r, θ))   ℯ
#          2⋅γ(u, r, θ) ∂                                           ∂θ
# , r, θ)⋅ℯ            ⋅──(U(u, r, θ)) + ───────────────────────────────────────── + ─────────
#                       ∂θ                                   r
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                  2
#
#
#
#
#                                                                                           0
#
#
#                                                                                           ⎛
#   2⋅β(u, r, θ) ∂                 2⋅β(u, r, θ) ∂             ⎞                             ⎜
# ⋅ℯ            ⋅──(β(u, r, θ))   ℯ            ⋅──(V(u, r, θ))⎟                             ⎜
#                ∂θ                             ∂θ            ⎟             -2⋅β(u, r, θ)   ⎜2
# ───────────────────────────── - ────────────────────────────⎟⋅U(u, r, θ)⋅ℯ                ⎜
#         r                                    r              ⎠                             ⎝
# ─────────────────────────────────────────────────────────────────────────────────────── - ──
#
#
#
#
#                 2             2⋅γ(u, r, θ) ∂                     2           2⋅γ(u, r, θ)
# (u, r, θ)) - 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(U(u, r, θ)) - 2⋅r⋅U (u, r, θ)⋅ℯ             +
#                                            ∂r
#
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                     2
#
# , θ) ∂             ⎞
#     ⋅──(V(u, r, θ))⎟
#      ∂θ            ⎟  -2⋅β(u, r, θ)   ⎛     2             2⋅γ(u, r, θ) ∂                 2
# ───────────────────⎟⋅ℯ                ⎜- 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) - r ⋅ℯ
#     r              ⎠                  ⎝                                ∂r
# ─────────────────────────────────── - ──────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#   2  2           2⋅γ(u, r, θ) ∂                   2             2⋅γ(u, r, θ) ∂
# ⋅r ⋅U (u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) + 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(U(u, r, θ))
#                               ∂r                                             ∂r
#
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#               2⋅β(u, r, θ) ∂                 2⋅β(u, r, θ) ∂
# 2⋅V(u, r, θ)⋅ℯ            ⋅──(β(u, r, θ))   ℯ            ⋅──(V(u, r, θ))               2⋅β(u
#                            ∂r                             ∂r               V(u, r, θ)⋅ℯ
# ───────────────────────────────────────── + ──────────────────────────── - ─────────────────
#                     r                                    r                             2
#                                                                                       r
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
# 2⋅γ(u, r, θ) ∂                                2⋅γ(u, r, θ)      2⋅β(u, r, θ) ∂             ⎞
#             ⋅──(U(u, r, θ)) - 2⋅r⋅U(u, r, θ)⋅ℯ             + 2⋅ℯ            ⋅──(β(u, r, θ))⎟
#              ∂r                                                              ∂θ            ⎠
# ────────────────────────────────────────────────────────────────────────────────────────────
#                               2⋅r
#
#
#
#
#
#
#
#                                                                                  2⋅β(u, r, θ
#                                                                    2⋅V(u, r, θ)⋅ℯ
#        2           2⋅γ(u, r, θ)      2⋅β(u, r, θ) ∂
# + 2⋅r⋅U (u, r, θ)⋅ℯ             + 4⋅ℯ            ⋅──(β(u, r, θ)) - ─────────────────────────
#                                                   ∂u                                   r
#
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                 2⋅r
#
#        ⎞
# , r, θ)⎟
#        ⎟  -2⋅β(u, r, θ)
# ───────⎟⋅ℯ
#        ⎟
#        ⎠
# ───────────────────────
#
#
#
#
#              -2⋅β(u, r, θ)
# ⋅V(u, r, θ)⋅ℯ
#
# ──────────────────────────
#
#
#
#
#
#
#
#
# ) ∂                 2⋅β(u, r, θ) ∂                                        ⎞
#  ⋅──(β(u, r, θ))   ℯ            ⋅──(V(u, r, θ))               2⋅β(u, r, θ)⎟
#   ∂r                             ∂r               V(u, r, θ)⋅ℯ            ⎟             -2⋅β
# ──────────────── - ──────────────────────────── + ────────────────────────⎟⋅V(u, r, θ)⋅ℯ
#                                 r                             2           ⎟
#                                                              r            ⎠
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (u, r, θ)
#            ⎛   2             2⋅γ(u, r, θ) ∂                 2  2⋅γ(u, r, θ) ∂
#            ⎜2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) + r ⋅ℯ            ⋅──(U(u, r, θ)) +
#            ⎝                              ∂r                                ∂r
# ─────────  ─────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                  2⋅γ(u, r, θ)      2⋅β(u, r, θ) ∂             ⎞             -2⋅β(u, r, θ)
#  2⋅r⋅U(u, r, θ)⋅ℯ             - 2⋅ℯ            ⋅──(β(u, r, θ))⎟⋅U(u, r, θ)⋅ℯ
#                                                 ∂θ            ⎠
# ───────────────────────────────────────────────────────────────────────────────────────── +
#    2
#
#
#
#
#
#
#
#
#
#
#
#
#      ⎛     2  2⋅γ(u, r, θ) ∂                     2⋅γ(u, r, θ)⎞             -2⋅β(u, r, θ)   ⎛
#      ⎜- 2⋅r ⋅ℯ            ⋅──(γ(u, r, θ)) - 2⋅r⋅ℯ            ⎟⋅U(u, r, θ)⋅ℯ                ⎜
#      ⎝                     ∂r                                ⎠                             ⎝
#      ─────────────────────────────────────────────────────────────────────────────────── + ─
#                                               2
#
#
#
#
#
#
#
# ⎛
# ⎜
# ⎜     2  2           2⋅γ(u, r, θ) ∂                   2             2⋅γ(u, r, θ) ∂
# ⎜- 2⋅r ⋅U (u, r, θ)⋅ℯ            ⋅──(γ(u, r, θ)) - 2⋅r ⋅U(u, r, θ)⋅ℯ            ⋅──(U(u, r,
# ⎜                                 ∂r                                             ∂r
# ⎝
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                               ∂
#                             2⋅──(β(u, r, θ))
#                               ∂r
#
#
# ...
#      ∂u
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      ⎛     2  -2⋅γ(u, r, θ)    2    ∂                     -2⋅γ(u, r, θ)    2
#                      ⎜- 2⋅r ⋅ℯ             ⋅sin (θ)⋅──(γ(u, r, θ)) + 2⋅r⋅ℯ             ⋅sin
#                      ⎝                              ∂r
#                      ───────────────────────────────────────────────────────────────────────
#                                                                        2
#
#
#
#
#
#
#
#
#
#                              0
#
#
#
#
#
#
#                              0
#
#
#
#
#
#
#                              0
#
#
#
#    ⎞             -2⋅β(u, r, θ)   ⎛     2  -2⋅γ(u, r, θ)    2    ∂                   2  -2⋅γ(
# (θ)⎟⋅U(u, r, θ)⋅ℯ                ⎜- 2⋅r ⋅ℯ             ⋅sin (θ)⋅──(γ(u, r, θ)) + 2⋅r ⋅ℯ
#    ⎠                             ⎝                              ∂θ
# ────────────────────────────── - ───────────────────────────────────────────────────────────
#                                                                                    2
#                                                                                 2⋅r
#
#
#                                       ⎤
#                                       ⎥
#                                       ⎥
#                                       ⎥  ⎡
#                                       ⎥  ⎢       0
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢       0
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢       0
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢
#                                       ⎥  ⎢                  ⎛   2  -2⋅γ(u, r, θ)    2    ∂
#                                       ⎥  ⎢                 -⎜2⋅r ⋅ℯ             ⋅sin (θ)⋅──(
#                                       ⎥  ⎢ ∂                ⎝                            ∂r
# u, r, θ)              ⎞  -2⋅γ(u, r, θ)⎥  ⎢-──(γ(u, r, θ))  ─────────────────────────────────
#         ⋅sin(θ)⋅cos(θ)⎟⋅ℯ             ⎥  ⎢ ∂u
#                       ⎠               ⎥  ⎣
# ──────────────────────────────────────⎥
#                                       ⎥
#                                       ⎦
#
#
#
#
#
#
#            0
#
#
#
#
#
#            0
#
#
#
#
#
#
#            0
#
#
#
#                    -2⋅γ(u, r, θ)    2   ⎞  2⋅γ(u, r, θ)    ⎛   2  -2⋅γ(u, r, θ)    2    ∂
# γ(u, r, θ)) - 2⋅r⋅ℯ             ⋅sin (θ)⎟⋅ℯ               -⎜2⋅r ⋅ℯ             ⋅sin (θ)⋅──(γ
#                                         ⎠                  ⎝                            ∂θ
# ────────────────────────────────────────────────────────  ──────────────────────────────────
#          2    2
#       2⋅r ⋅sin (θ)
#
#
#
#
#
#
#
#
#
#              0
#
#
#                                                                     ⎛   2  -2⋅γ(u, r, θ)
#                                                                    -⎜2⋅r ⋅ℯ             ⋅sin
#                                                                     ⎝
#              0                                                     ─────────────────────────
#
#
#
#                                                                  ⎛   2  -2⋅γ(u, r, θ)    2
#                                                                 -⎜2⋅r ⋅ℯ             ⋅sin (θ
#                                                                  ⎝
#              0                                                  ────────────────────────────
#
#
#
#                 2  -2⋅γ(u, r, θ)              ⎞  2⋅γ(u, r, θ)
# (u, r, θ)) - 2⋅r ⋅ℯ             ⋅sin(θ)⋅cos(θ)⎟⋅ℯ
#                                               ⎠
# ──────────────────────────────────────────────────────────────
#            2    2
#         2⋅r ⋅sin (θ)
#
#
#
#
#
#                                                                      ⎤
#                                                                      ⎥
#                                                                      ⎥
#              ∂                                                      ⎤⎥
#             -──(γ(u, r, θ))                                         ⎥⎥
#              ∂u                                                     ⎥⎥
#                                                                     ⎥⎥
# 2    ∂                     -2⋅γ(u, r, θ)    2   ⎞  2⋅γ(u, r, θ)     ⎥⎥
#  (θ)⋅──(γ(u, r, θ)) - 2⋅r⋅ℯ             ⋅sin (θ)⎟⋅ℯ                 ⎥⎥
#      ∂r                                         ⎠                   ⎥⎥
# ────────────────────────────────────────────────────────────────    ⎥⎥
#                  2    2                                             ⎥⎥
#               2⋅r ⋅sin (θ)                                          ⎥⎥
#                                                                     ⎥⎥
#   ∂                   2  -2⋅γ(u, r, θ)              ⎞  2⋅γ(u, r, θ) ⎥⎥
# )⋅──(γ(u, r, θ)) - 2⋅r ⋅ℯ             ⋅sin(θ)⋅cos(θ)⎟⋅ℯ             ⎥⎥
#   ∂θ                                                ⎠               ⎥⎥
# ────────────────────────────────────────────────────────────────────⎥⎥
#                  2    2                                             ⎥⎥
#               2⋅r ⋅sin (θ)                                          ⎥⎥
#                                                                     ⎥⎥
#                                                                     ⎥⎥
#                                                                     ⎥⎥
#                                                                     ⎥⎥
#                    0                                                ⎥⎥
#                                                                     ⎥⎥
#                                                                     ⎦⎥
#                                                                      ⎥
#                                                                      ⎥
#                                                                      ⎥
#                                                                      ⎦

# %%
expand(ch.tensor()[0,0,0])
# Out:
#
#
#  2  2           -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                 2             -2⋅β(u, r, θ)  2
# r ⋅U (u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) + r ⋅U(u, r, θ)⋅ℯ             ⋅ℯ
#                                             ∂r
#
#
#
#
# ⋅γ(u, r, θ) ∂                   2           -2⋅β(u, r, θ)  2⋅γ(u, r, θ)     ∂
#            ⋅──(U(u, r, θ)) + r⋅U (u, r, θ)⋅ℯ             ⋅ℯ             + 2⋅──(β(u, r, θ)) -
#             ∂r                                                              ∂u
#
#
#             ∂                ∂
#  V(u, r, θ)⋅──(β(u, r, θ))   ──(V(u, r, θ))
#             ∂r               ∂r               V(u, r, θ)
#  ───────────────────────── - ────────────── + ──────────
#              r                    2⋅r               2
#                                                  2⋅r

# %%
expand(ch.tensor()[0,0,2])
# Out:
#                                                                2  -2⋅β(u, r, θ)  2⋅γ(u, r, θ
#                                                               r ⋅ℯ             ⋅ℯ
#    2             -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂
# - r ⋅U(u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) - ──────────────────────────────
#                                              ∂r                                     2
#
# ) ∂
#  ⋅──(U(u, r, θ))
#   ∂r                             -2⋅β(u, r, θ)  2⋅γ(u, r, θ)   ∂
# ──────────────── - r⋅U(u, r, θ)⋅ℯ             ⋅ℯ             + ──(β(u, r, θ))
#                                                                ∂θ

# %%
expand(ch.tensor()[0,2,2])
# Out:
#  2  -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                   -2⋅β(u, r, θ)  2⋅γ(u, r, θ)
# r ⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) + r⋅ℯ             ⋅ℯ
#                                 ∂r

# %%
expand(ch.tensor()[0,3,3])
# Out:
#    2  -2⋅β(u, r, θ)  -2⋅γ(u, r, θ)    2    ∂                   -2⋅β(u, r, θ)  -2⋅γ(u, r, θ)
# - r ⋅ℯ             ⋅ℯ             ⋅sin (θ)⋅──(γ(u, r, θ)) + r⋅ℯ             ⋅ℯ             ⋅
#                                            ∂r
#
#    2
# sin (θ)

# %%
expand(ch.tensor()[1,0,0])
# Out:
#
#
#  2  3           -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                 2  2           -2⋅β(u, r, θ)
# r ⋅U (u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) + r ⋅U (u, r, θ)⋅ℯ             ⋅ℯ
#                                             ∂θ
#
#
#
#
# 2⋅γ(u, r, θ) ∂                 2  2           -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂
#             ⋅──(U(u, r, θ)) + r ⋅U (u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) - r
#              ∂θ                                                           ∂u
#
#
#
#
#   2                      -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂
# ⋅U (u, r, θ)⋅V(u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) - r⋅U(u, r, θ)⋅V(u, r, θ
#                                                      ∂r
#
#
#
#
#    -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                 2                      -2⋅β(u, r, θ)  2⋅γ(u
# )⋅ℯ             ⋅ℯ            ⋅──(U(u, r, θ)) - U (u, r, θ)⋅V(u, r, θ)⋅ℯ             ⋅ℯ
#                                ∂r
#
#
#                                 ∂                           ∂                           ∂
#           U(u, r, θ)⋅V(u, r, θ)⋅──(β(u, r, θ))   U(u, r, θ)⋅──(V(u, r, θ))   V(u, r, θ)⋅──(β
# , r, θ)                         ∂θ                          ∂θ                          ∂u
#         - ──────────────────────────────────── - ───────────────────────── - ───────────────
#                            r                                2⋅r                          r
#
#
#              ∂                 2          ∂                           ∂
# (u, r, θ))   ──(V(u, r, θ))   V (u, r, θ)⋅──(β(u, r, θ))   V(u, r, θ)⋅──(V(u, r, θ))    2
#              ∂u                           ∂r                          ∂r               V (u,
# ────────── + ────────────── + ────────────────────────── + ───────────────────────── - ─────
#                   2⋅r                      2                             2
#                                           r                           2⋅r                  2
#
#
#
#  r, θ)
# ──────
#   3
# ⋅r

# %%
expand(ch.tensor()[1,0,1])
# Out:
#    2             -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂
#   r ⋅U(u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(U(u, r, θ))                               V(
#                                              ∂r                          ∂
# - ───────────────────────────────────────────────────────── - U(u, r, θ)⋅──(β(u, r, θ)) + ──
#                               2                                          ∂θ
#
#
#          ∂                ∂
# u, r, θ)⋅──(β(u, r, θ))   ──(V(u, r, θ))
#          ∂r               ∂r               V(u, r, θ)
# ─────────────────────── + ────────────── - ──────────
#           r                    2⋅r               2
#                                               2⋅r

# %%
expand(ch.tensor()[1,0,2])
# Out:
#
#
#    2  2           -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                 2             -2⋅β(u, r, θ)
# - r ⋅U (u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) - r ⋅U(u, r, θ)⋅ℯ             ⋅
#                                               ∂θ
#
#
#
#  2⋅γ(u, r, θ) ∂                 2             -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂
# ℯ            ⋅──(U(u, r, θ)) - r ⋅U(u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) + r
#               ∂θ                                                          ∂u
#
#                                                                                    -2⋅β(u, r
#                                                                      r⋅V(u, r, θ)⋅ℯ
#                         -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂
# ⋅U(u, r, θ)⋅V(u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) + ───────────────────────
#                                                     ∂r
#
# , θ)  2⋅γ(u, r, θ) ∂                                                                     ∂
#     ⋅ℯ            ⋅──(U(u, r, θ))                                                        ──(
#                    ∂r                                      -2⋅β(u, r, θ)  2⋅γ(u, r, θ)   ∂θ
# ───────────────────────────────── + U(u, r, θ)⋅V(u, r, θ)⋅ℯ             ⋅ℯ             + ───
#     2
#
#
# V(u, r, θ))
#
# ───────────
#   2⋅r

# %%
expand(ch.tensor()[1,1,1])
# Out:
#   ∂
# 2⋅──(β(u, r, θ))
#   ∂r

# %%
expand(ch.tensor()[1,1,2])
# Out:
#  2  -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂
# r ⋅ℯ             ⋅ℯ            ⋅──(U(u, r, θ))
#                                 ∂r               ∂
# ────────────────────────────────────────────── + ──(β(u, r, θ))
#                       2                          ∂θ

# %%
expand(ch.tensor()[1,2,2])
# Out:
#  2             -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                 2  -2⋅β(u, r, θ)  2⋅γ(u, r, θ)
# r ⋅U(u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) + r ⋅ℯ             ⋅ℯ            ⋅
#                                            ∂θ
#
# ∂                 2  -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                              -2⋅β(u, r, θ
# ──(U(u, r, θ)) + r ⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) - r⋅V(u, r, θ)⋅ℯ
# ∂θ                                               ∂u
#
# )  2⋅γ(u, r, θ) ∂                            -2⋅β(u, r, θ)  2⋅γ(u, r, θ)
#  ⋅ℯ            ⋅──(γ(u, r, θ)) - V(u, r, θ)⋅ℯ             ⋅ℯ
#                 ∂r

# %%
expand(ch.tensor()[1,3,3])
# Out:
#    2             -2⋅β(u, r, θ)  -2⋅γ(u, r, θ)    2    ∂                 2             -2⋅β(u
# - r ⋅U(u, r, θ)⋅ℯ             ⋅ℯ             ⋅sin (θ)⋅──(γ(u, r, θ)) + r ⋅U(u, r, θ)⋅ℯ
#                                                       ∂θ
#
# , r, θ)  -2⋅γ(u, r, θ)                  2  -2⋅β(u, r, θ)  -2⋅γ(u, r, θ)    2    ∂
#        ⋅ℯ             ⋅sin(θ)⋅cos(θ) - r ⋅ℯ             ⋅ℯ             ⋅sin (θ)⋅──(γ(u, r, θ
#                                                                                 ∂u
#
#                    -2⋅β(u, r, θ)  -2⋅γ(u, r, θ)    2    ∂                            -2⋅β(u,
# )) + r⋅V(u, r, θ)⋅ℯ             ⋅ℯ             ⋅sin (θ)⋅──(γ(u, r, θ)) - V(u, r, θ)⋅ℯ
#                                                         ∂r
#
#  r, θ)  -2⋅γ(u, r, θ)    2
#       ⋅ℯ             ⋅sin (θ)

# %%
expand(ch.tensor()[2,0,0])
# Out:
#
#
#  2  3           -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                 2  2           -2⋅β(u, r, θ)
# r ⋅U (u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) + r ⋅U (u, r, θ)⋅ℯ             ⋅ℯ
#                                             ∂r
#
#
#
#
# 2⋅γ(u, r, θ) ∂                   3           -2⋅β(u, r, θ)  2⋅γ(u, r, θ)    2          ∂
#             ⋅──(U(u, r, θ)) + r⋅U (u, r, θ)⋅ℯ             ⋅ℯ             - U (u, r, θ)⋅──(γ(
#              ∂r                                                                        ∂θ
#
#
#
#
#                        ∂                             ∂                             ∂
# u, r, θ)) - U(u, r, θ)⋅──(U(u, r, θ)) + 2⋅U(u, r, θ)⋅──(β(u, r, θ)) - 2⋅U(u, r, θ)⋅──(γ(u, r
#                        ∂θ                            ∂u                            ∂u
#
#
#                                                ∂                           ∂
#                          U(u, r, θ)⋅V(u, r, θ)⋅──(β(u, r, θ))   U(u, r, θ)⋅──(V(u, r, θ))
#         ∂                                      ∂r                          ∂r
# , θ)) - ──(U(u, r, θ)) - ──────────────────────────────────── - ───────────────────────── +
#         ∂u                                r                                2⋅r
#
#
#                                     2⋅β(u, r, θ)  -2⋅γ(u, r, θ) ∂                 2⋅β(u, r,
#                         V(u, r, θ)⋅ℯ            ⋅ℯ             ⋅──(β(u, r, θ))   ℯ
# U(u, r, θ)⋅V(u, r, θ)                                           ∂θ
# ───────────────────── + ────────────────────────────────────────────────────── + ───────────
#             2                                      3
#          2⋅r                                      r
#
# θ)  -2⋅γ(u, r, θ) ∂
#   ⋅ℯ             ⋅──(V(u, r, θ))
#                   ∂θ
# ────────────────────────────────
#             3
#          2⋅r

# %%
expand(ch.tensor()[2,0,1])
# Out:
#                               ∂                              2⋅β(u, r, θ)  -2⋅γ(u, r, θ) ∂
#                               ──(U(u, r, θ))                ℯ            ⋅ℯ             ⋅──(
#              ∂                ∂r               U(u, r, θ)                                ∂θ
# - U(u, r, θ)⋅──(γ(u, r, θ)) - ────────────── - ────────── + ────────────────────────────────
#              ∂r                     2              r                              2
#                                                                                  r
#
#
# β(u, r, θ))
#
# ───────────

# %%
expand(ch.tensor()[2,0,2])
# Out:
#                                                                 2             -2⋅β(u, r, θ)
#                                                                r ⋅U(u, r, θ)⋅ℯ             ⋅
#    2  2           -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂
# - r ⋅U (u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) - ─────────────────────────────
#                                               ∂r                                           2
#
#  2⋅γ(u, r, θ) ∂
# ℯ            ⋅──(U(u, r, θ))
#               ∂r                  2           -2⋅β(u, r, θ)  2⋅γ(u, r, θ)              ∂
# ──────────────────────────── - r⋅U (u, r, θ)⋅ℯ             ⋅ℯ             + U(u, r, θ)⋅──(β(
#                                                                                        ∂θ
#
#
#
#             ∂
# u, r, θ)) + ──(γ(u, r, θ))
#             ∂u

# %%
expand(ch.tensor()[2,1,2])
# Out:
# ∂                1
# ──(γ(u, r, θ)) + ─
# ∂r               r

# %%
expand(ch.tensor()[2,2,2])
# Out:
#  2             -2⋅β(u, r, θ)  2⋅γ(u, r, θ) ∂                              -2⋅β(u, r, θ)  2⋅γ
# r ⋅U(u, r, θ)⋅ℯ             ⋅ℯ            ⋅──(γ(u, r, θ)) + r⋅U(u, r, θ)⋅ℯ             ⋅ℯ
#                                            ∂r
#
# (u, r, θ)   ∂
#           + ──(γ(u, r, θ))
#             ∂θ

# %%
expand(ch.tensor()[2,3,3])
# Out:
#    2             -2⋅β(u, r, θ)  -2⋅γ(u, r, θ)    2    ∂                              -2⋅β(u,
# - r ⋅U(u, r, θ)⋅ℯ             ⋅ℯ             ⋅sin (θ)⋅──(γ(u, r, θ)) + r⋅U(u, r, θ)⋅ℯ
#                                                       ∂r
#
#  r, θ)  -2⋅γ(u, r, θ)    2       -4⋅γ(u, r, θ)    2    ∂                 -4⋅γ(u, r, θ)
#       ⋅ℯ             ⋅sin (θ) + ℯ             ⋅sin (θ)⋅──(γ(u, r, θ)) - ℯ             ⋅sin(θ
#                                                        ∂θ
#
#
# )⋅cos(θ)

# %%
expand(ch.tensor()[3,0,3])
# Out:
#  ∂
# -──(γ(u, r, θ))
#  ∂u

# %%
expand(ch.tensor()[3,1,3])
# Out:
#   ∂                1
# - ──(γ(u, r, θ)) + ─
#   ∂r               r

# %%
expand(ch.tensor()[3,2,3])
# Out:
#   ∂                cos(θ)
# - ──(γ(u, r, θ)) + ──────
#   ∂θ               sin(θ)

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr

# %%
rm1 = RiemannCurvatureTensor.from_christoffels(ch)
rm1.tensor()

# %%
weyl = WeylTensor.from_metric(metric)
weyl.tensor()
