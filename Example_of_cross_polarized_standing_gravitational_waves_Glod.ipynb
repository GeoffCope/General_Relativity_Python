# %% [markdown]
# # Example of cross-polarized standing gravitational waves by Glod et al
# ##  Geoff Cope
# ##  Univeristy of Utah
# ##  January 5th, 2022

# %% [markdown]
# Here we work with the metric given in the equation numbered equation 11 in the Appendix.  Will come back and do the first metric later.  TO DO:  Actually solve this system and get the solutions they have listed in back.

# %% [markdown]
# https://arxiv.org/pdf/2106.05829.pdf

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
t,rho,phi,z,dt,drho,dphi,dz = symbols('t rho phi z dt drho dphi dz')

# %%
gamma = Function('gamma')(t,rho)
gamma
# Out:
# γ(t, ρ)

# %%
omega = Function('omega')(t,rho)
omega
# Out:
# ω(t, ρ)

# %%
psi = Function('psi')(t,rho)
psi
# Out:
# ψ(t, ρ)

# %%
variables = Matrix( [t,rho,phi,z] )
variables
# Out:
# ⎡t⎤
# ⎢ ⎥
# ⎢ρ⎥
# ⎢ ⎥
# ⎢φ⎥
# ⎢ ⎥
# ⎣z⎦

# %%
differentials = Matrix( [dt,drho,dphi,dz] ) 
differentials
# Out:
# ⎡ dt ⎤
# ⎢    ⎥
# ⎢drho⎥
# ⎢    ⎥
# ⎢dphi⎥
# ⎢    ⎥
# ⎣ dz ⎦

# %%
lineElement = expand( exp(2*(gamma - psi)) * (-dt**2 + drho**2) +( rho**2 * exp( - 2*psi) * dphi**2) + exp(2*psi)*(dz + omega * dphi )**2 ) 
lineElement
# Out:
#     2  2  -2⋅ψ(t, ρ)       2  2        2⋅ψ(t, ρ)                      2⋅ψ(t, ρ)       2  2⋅γ
# dphi ⋅ρ ⋅ℯ           + dphi ⋅ω (t, ρ)⋅ℯ          + 2⋅dphi⋅dz⋅ω(t, ρ)⋅ℯ          + drho ⋅ℯ
#
# (t, ρ)  -2⋅ψ(t, ρ)     2  2⋅γ(t, ρ)  -2⋅ψ(t, ρ)     2  2⋅ψ(t, ρ)
#       ⋅ℯ           - dt ⋅ℯ         ⋅ℯ           + dz ⋅ℯ

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡  2⋅γ(t, ρ)  -2⋅ψ(t, ρ)
# ⎢-ℯ         ⋅ℯ                      0                              0
# ⎢
# ⎢                          2⋅γ(t, ρ)  -2⋅ψ(t, ρ)
# ⎢           0             ℯ         ⋅ℯ                             0
# ⎢
# ⎢                                                  2  -2⋅ψ(t, ρ)    2        2⋅ψ(t, ρ)
# ⎢           0                       0             ρ ⋅ℯ           + ω (t, ρ)⋅ℯ           ω(t,
# ⎢
# ⎢                                                                   2⋅ψ(t, ρ)
# ⎣           0                       0                      ω(t, ρ)⋅ℯ
#
#               ⎤
#     0         ⎥
#               ⎥
#               ⎥
#     0         ⎥
#               ⎥
#      2⋅ψ(t, ρ)⎥
#  ρ)⋅ℯ         ⎥
#               ⎥
#  2⋅ψ(t, ρ)    ⎥
# ℯ             ⎦

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡  2⋅γ(t, ρ)  -2⋅ψ(t, ρ)
# ⎢-ℯ         ⋅ℯ                      0                              0
# ⎢
# ⎢                          2⋅γ(t, ρ)  -2⋅ψ(t, ρ)
# ⎢           0             ℯ         ⋅ℯ                             0
# ⎢
# ⎢                                                  2  -2⋅ψ(t, ρ)    2        2⋅ψ(t, ρ)
# ⎢           0                       0             ρ ⋅ℯ           + ω (t, ρ)⋅ℯ           ω(t,
# ⎢
# ⎢                                                                   2⋅ψ(t, ρ)
# ⎣           0                       0                      ω(t, ρ)⋅ℯ
#
#               ⎤
#     0         ⎥
#               ⎥
#               ⎥
#     0         ⎥
#               ⎥
#      2⋅ψ(t, ρ)⎥
#  ρ)⋅ℯ         ⎥
#               ⎥
#  2⋅ψ(t, ρ)    ⎥
# ℯ             ⎦

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("t rho phi z")
t,rho,phi,z = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
simplify(ch.tensor())
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢⎡∂             ∂            ∂             ∂
# ⎢⎢──(γ(t, ρ)) - ──(ψ(t, ρ))  ──(γ(t, ρ)) - ──(ψ(t, ρ))
# ⎢⎢∂t            ∂t           ∂ρ            ∂ρ
# ⎢⎢
# ⎢⎢∂             ∂            ∂             ∂
# ⎢⎢──(γ(t, ρ)) - ──(ψ(t, ρ))  ──(γ(t, ρ)) - ──(ψ(t, ρ))
# ⎢⎢∂ρ            ∂ρ           ∂t            ∂t
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                      ⎛   2 ∂             ⎛        ∂
# ⎢⎢            0                          0              ⎜- ρ ⋅──(ψ(t, ρ)) + ⎜ω(t, ρ)⋅──(ψ(t,
# ⎢⎢                                                      ⎝     ∂t            ⎝        ∂t
# ⎢⎢
# ⎢⎢                                                                    ⎛
# ⎢⎢                                                                    ⎜
# ⎢⎢                                                                    ⎜        ∂
# ⎢⎢            0                          0                            ⎜ω(t, ρ)⋅──(ψ(t, ρ)) +
# ...

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()
# Out:
# ⎡
# ⎢                                                                               ∂
# ⎢  2              2              2                           2     2            ──(γ(t, ρ))
# ⎢ ∂              ∂              ∂               ⎛∂          ⎞     ∂             ∂ρ
# ⎢───(γ(t, ρ)) - ───(γ(t, ρ)) - ───(ψ(t, ρ)) - 2⋅⎜──(ψ(t, ρ))⎟  + ───(ψ(t, ρ)) + ───────────
# ⎢  2              2              2              ⎝∂t         ⎠      2                 ρ
# ⎢∂ρ             ∂t             ∂ρ                                ∂t
# ⎢
# ⎢
# ⎢                                                         ∂              4⋅ψ(t, ρ) ∂
# ⎢                                                         ──(γ(t, ρ))   ℯ         ⋅──(ω(t, ρ
# ⎢                               ∂           ∂             ∂t                       ∂ρ
# ⎢                           - 2⋅──(ψ(t, ρ))⋅──(ψ(t, ρ)) + ─────────── - ────────────────────
# ⎢                               ∂ρ          ∂t                 ρ                          2
# ...

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr
# Out:
# ⎛         2                   2                              2          2
# ⎜     2  ∂                2  ∂                2 ⎛∂          ⎞       2  ∂                2 ⎛∂
# ⎜- 4⋅ρ ⋅───(γ(t, ρ)) + 4⋅ρ ⋅───(γ(t, ρ)) - 4⋅ρ ⋅⎜──(ψ(t, ρ))⎟  + 4⋅ρ ⋅───(ψ(t, ρ)) + 4⋅ρ ⋅⎜─
# ⎜         2                   2                 ⎝∂ρ         ⎠           2                 ⎝∂
# ⎝       ∂ρ                  ∂t                                        ∂ρ
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#            2          2                                                      2
#           ⎞       2  ∂                 ∂              4⋅ψ(t, ρ) ⎛∂          ⎞     4⋅ψ(t, ρ)
# ─(ψ(t, ρ))⎟  - 4⋅ρ ⋅───(ψ(t, ρ)) + 4⋅ρ⋅──(ψ(t, ρ)) - ℯ         ⋅⎜──(ω(t, ρ))⎟  + ℯ         ⋅
# t         ⎠           2                ∂ρ                       ⎝∂ρ         ⎠
#                     ∂t
# ...

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()
# Out:
# ⎡
# ⎢
# ⎢                                                                               ∂
# ⎢  2              2              2                           2     2            ──(γ(t, ρ))
# ⎢ ∂              ∂              ∂               ⎛∂          ⎞     ∂             ∂ρ
# ⎢───(γ(t, ρ)) - ───(γ(t, ρ)) - ───(ψ(t, ρ)) - 2⋅⎜──(ψ(t, ρ))⎟  + ───(ψ(t, ρ)) + ───────────
# ⎢  2              2              2              ⎝∂t         ⎠      2                 ρ
# ⎢∂ρ             ∂t             ∂ρ                                ∂t
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                      ⎛         2                   2                              2
#                      ⎜     2  ∂                2  ∂                2 ⎛∂          ⎞       2
#   ∂             0.25⋅⎜- 4⋅ρ ⋅───(γ(t, ρ)) + 4⋅ρ ⋅───(γ(t, ρ)) - 4⋅ρ ⋅⎜──(ψ(t, ρ))⎟  + 4⋅ρ ⋅─
# ...

# %%
#  rm1 = RiemannCurvatureTensor.from_christoffels(ch)
#  rm1.tensor()

# %%
#  weyl = WeylTensor.from_metric(metric)
#  weyl.tensor()

# %%
ricciSimplified = simplify(Ric.tensor())
ricciSimplified
# Out:
# ⎡
# ⎢                                                                               ∂
# ⎢  2              2              2                           2     2            ──(γ(t, ρ))
# ⎢ ∂              ∂              ∂               ⎛∂          ⎞     ∂             ∂ρ
# ⎢───(γ(t, ρ)) - ───(γ(t, ρ)) - ───(ψ(t, ρ)) - 2⋅⎜──(ψ(t, ρ))⎟  + ───(ψ(t, ρ)) + ───────────
# ⎢  2              2              2              ⎝∂t         ⎠      2                 ρ
# ⎢∂ρ             ∂t             ∂ρ                                ∂t
# ⎢
# ⎢
# ⎢                                                         ∂              4⋅ψ(t, ρ) ∂
# ⎢                                                         ──(γ(t, ρ))   ℯ         ⋅──(ω(t, ρ
# ⎢                               ∂           ∂             ∂t                       ∂ρ
# ⎢                           - 2⋅──(ψ(t, ρ))⋅──(ψ(t, ρ)) + ─────────── - ────────────────────
# ⎢                               ∂ρ          ∂t                 ρ                          2
# ...

# %%
einsteinSimplified = simplify(einst.tensor())
einsteinSimplified
# Out:
# ⎡                                                                                   2
# ⎢                                        ∂                   4⋅ψ(t, ρ) ⎛∂          ⎞
# ⎢               2                2   1.0⋅──(γ(t, ρ))   0.25⋅ℯ         ⋅⎜──(ω(t, ρ))⎟    0.25
# ⎢  ⎛∂          ⎞    ⎛∂          ⎞        ∂ρ                            ⎝∂ρ         ⎠
# ⎢- ⎜──(ψ(t, ρ))⎟  - ⎜──(ψ(t, ρ))⎟  + ─────────────── - ────────────────────────────── - ────
# ⎢  ⎝∂ρ         ⎠    ⎝∂t         ⎠           ρ                         2
# ⎢                                                                    ρ
# ⎢
# ⎢
# ⎢                                                 ∂              4⋅ψ(t, ρ) ∂           ∂
# ⎢                                                 ──(γ(t, ρ))   ℯ         ⋅──(ω(t, ρ))⋅──(ω(
# ⎢                       ∂           ∂             ∂t                       ∂ρ          ∂t
# ⎢                   - 2⋅──(ψ(t, ρ))⋅──(ψ(t, ρ)) + ─────────── - ────────────────────────────
# ...

# %%
psiWave = expand((1/rho**2)*ricciSimplified[3,3].args[1])
psiWave
# Out:
#                                                                       2
#                                 ∂              4⋅ψ(t, ρ) ⎛∂          ⎞     4⋅ψ(t, ρ) ⎛∂
#     2              2            ──(ψ(t, ρ))   ℯ         ⋅⎜──(ω(t, ρ))⎟    ℯ         ⋅⎜──(ω(t
#    ∂              ∂             ∂ρ                       ⎝∂ρ         ⎠               ⎝∂t
# - ───(ψ(t, ρ)) + ───(ψ(t, ρ)) - ─────────── + ───────────────────────── - ──────────────────
#     2              2                 ρ                      2                           2
#   ∂ρ             ∂t                                      2⋅ρ                         2⋅ρ
#
#       2
#      ⎞
# , ρ))⎟
#      ⎠
# ───────

# %%
dgammadt = Eq(diff(gamma,t) , solve( Ric.tensor()[1,0] , diff(gamma,t) )[0] ) 
dgammadt
# Out:
#                                              4⋅ψ(t, ρ) ∂           ∂
#                                             ℯ         ⋅──(ω(t, ρ))⋅──(ω(t, ρ))
# ∂                 ∂           ∂                        ∂ρ          ∂t
# ──(γ(t, ρ)) = 2⋅ρ⋅──(ψ(t, ρ))⋅──(ψ(t, ρ)) + ──────────────────────────────────
# ∂t                ∂ρ          ∂t                           2⋅ρ

# %%
dgammadrho = Eq( diff(gamma,rho) , expand( solve( einsteinSimplified[1,1] , diff(gamma,rho) )[0] ) )
dgammadrho
# Out:
#                                                                                            2
#                                                                   4.0⋅ψ(t, ρ) ⎛∂          ⎞
#                                  2                      2   0.25⋅ℯ           ⋅⎜──(ω(t, ρ))⎟
# ∂                   ⎛∂          ⎞          ⎛∂          ⎞                      ⎝∂ρ         ⎠
# ──(γ(t, ρ)) = 1.0⋅ρ⋅⎜──(ψ(t, ρ))⎟  + 1.0⋅ρ⋅⎜──(ψ(t, ρ))⎟  + ────────────────────────────────
# ∂ρ                  ⎝∂ρ         ⎠          ⎝∂t         ⎠                   ρ
#
#                                   2
#          4.0⋅ψ(t, ρ) ⎛∂          ⎞
#    0.25⋅ℯ           ⋅⎜──(ω(t, ρ))⎟
#                      ⎝∂t         ⎠
#  + ────────────────────────────────
#                   ρ

# %%
d2psidt2 = Eq( diff(psi,t,t), expand( solve( ricciSimplified[3,3].args[1] , diff(psi,t,t) )[0] ) ) 
d2psidt2
# Out:
#                                                                     2
#                               ∂              4⋅ψ(t, ρ) ⎛∂          ⎞     4⋅ψ(t, ρ) ⎛∂
#   2              2            ──(ψ(t, ρ))   ℯ         ⋅⎜──(ω(t, ρ))⎟    ℯ         ⋅⎜──(ω(t,
#  ∂              ∂             ∂ρ                       ⎝∂ρ         ⎠               ⎝∂t
# ───(ψ(t, ρ)) = ───(ψ(t, ρ)) + ─────────── - ───────────────────────── + ────────────────────
#   2              2                 ρ                      2                           2
# ∂t             ∂ρ                                      2⋅ρ                         2⋅ρ
#
#     2
#    ⎞
# ρ))⎟
#    ⎠
# ─────

# %%
omegaWave = Eq(diff(omega,t,t) , solve( ricciSimplified[2,2].args[1].subs(d2psidt2.args[0],d2psidt2.args[1] ), diff(omega,t,t) )[0] ) 
omegaWave
# Out:
#                                                                                       ∂
#   2                                          2                                        ──(ω(t
#  ∂               ∂           ∂              ∂               ∂           ∂             ∂ρ
# ───(ω(t, ρ)) = 4⋅──(ω(t, ρ))⋅──(ψ(t, ρ)) + ───(ω(t, ρ)) - 4⋅──(ω(t, ρ))⋅──(ψ(t, ρ)) - ──────
#   2              ∂ρ          ∂ρ              2              ∂t          ∂t                 ρ
# ∂t                                         ∂ρ
#
#
# , ρ))
#
# ─────

# %%
vacuumFieldEquations = Matrix([d2psidt2,omegaWave,dgammadt,dgammadrho])
vacuumFieldEquations
# Out:
# ⎡                                                                                   2
# ⎢                                             ∂              4⋅ψ(t, ρ) ⎛∂          ⎞     4⋅ψ
# ⎢                 2              2            ──(ψ(t, ρ))   ℯ         ⋅⎜──(ω(t, ρ))⎟    ℯ
# ⎢                ∂              ∂             ∂ρ                       ⎝∂ρ         ⎠
# ⎢               ───(ψ(t, ρ)) = ───(ψ(t, ρ)) + ─────────── - ───────────────────────── + ────
# ⎢                 2              2                 ρ                      2
# ⎢               ∂t             ∂ρ                                      2⋅ρ
# ⎢
# ⎢
# ⎢                 2                                          2
# ⎢                ∂               ∂           ∂              ∂               ∂           ∂
# ⎢               ───(ω(t, ρ)) = 4⋅──(ω(t, ρ))⋅──(ψ(t, ρ)) + ───(ω(t, ρ)) - 4⋅──(ω(t, ρ))⋅──(ψ
# ⎢                 2              ∂ρ          ∂ρ              2              ∂t          ∂t
# ...
