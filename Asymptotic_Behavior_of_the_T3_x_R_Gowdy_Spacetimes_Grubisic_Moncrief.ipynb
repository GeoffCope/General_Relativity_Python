# %% [markdown]
# # Asymptotic Behavior of the T 3 × R Gowdy Spacetimes by Grubisic and Moncrief
# ##  Geoff Cope
# ##  Univeristy of Utah
# ##  𐐏𐐭𐑌𐐲𐑂𐐲𐑉𐑅𐐮𐐻𐐨 𐐲𐑂 𐐏𐐭𐐻𐐫
# ##  January 20, 2022

# %% [markdown]
# https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.339.4317&rep=rep1&type=pdf

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
t,theta,x,y,dt,dtheta,dx,dy = symbols('t theta x y dt dtheta dx dy')

# %%
W = Function('W')(t,theta)
W
# Out:
# W(t, θ)

# %%
Phi = Function('Phi')(t,theta)
Phi
# Out:
# Φ(t, θ)

# %%
A = Function('A')(t,theta)
A
# Out:
# A(t, θ)

# %%
variables = Matrix([t,theta,x,y])
variables
# Out:
# ⎡t⎤
# ⎢ ⎥
# ⎢θ⎥
# ⎢ ⎥
# ⎢x⎥
# ⎢ ⎥
# ⎣y⎦

# %%
differentials = Matrix([dt,dtheta,dx,dy])
differentials
# Out:
# ⎡  dt  ⎤
# ⎢      ⎥
# ⎢dtheta⎥
# ⎢      ⎥
# ⎢  dx  ⎥
# ⎢      ⎥
# ⎣  dy  ⎦

# %%
lineElement = expand( exp(2*A)*( -exp(2*t)*dt**2 + dtheta**2) + exp(-t)*( cosh(W) + cos(Phi)*sinh(W))*dx**2 + 2*exp(-t)*sin(Phi)*sinh(W)*dx*dy + exp(-t)*( cosh(W)-cos(Phi) * sinh(W))*dy**2  )
lineElement
# Out:
#     2  2⋅t  2⋅A(t, θ)         2  2⋅A(t, θ)     2  -t                                2  -t
# - dt ⋅ℯ   ⋅ℯ          + dtheta ⋅ℯ          + dx ⋅ℯ  ⋅cos(Φ(t, θ))⋅sinh(W(t, θ)) + dx ⋅ℯ  ⋅co
#
#                        -t                                2  -t
# sh(W(t, θ)) + 2⋅dx⋅dy⋅ℯ  ⋅sin(Φ(t, θ))⋅sinh(W(t, θ)) - dy ⋅ℯ  ⋅cos(Φ(t, θ))⋅sinh(W(t, θ)) +
#
#   2  -t
# dy ⋅ℯ  ⋅cosh(W(t, θ))

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡  2⋅t  2⋅A(t, θ)
# ⎢-ℯ   ⋅ℯ               0                               0
# ⎢
# ⎢                   2⋅A(t, θ)
# ⎢       0          ℯ                                   0
# ⎢
# ⎢                               -t                               -t
# ⎢       0              0       ℯ  ⋅cos(Φ(t, θ))⋅sinh(W(t, θ)) + ℯ  ⋅cosh(W(t, θ))
# ⎢
# ⎢                                         -t                                          -t
# ⎣       0              0                 ℯ  ⋅sin(Φ(t, θ))⋅sinh(W(t, θ))            - ℯ  ⋅cos
#
#                                            ⎤
#                 0                          ⎥
#                                            ⎥
#                                            ⎥
#                 0                          ⎥
#                                            ⎥
#    -t                                      ⎥
#   ℯ  ⋅sin(Φ(t, θ))⋅sinh(W(t, θ))           ⎥
#                                            ⎥
#                            -t              ⎥
# ...

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡  2⋅t  2⋅A(t, θ)
# ⎢-ℯ   ⋅ℯ               0                               0
# ⎢
# ⎢                   2⋅A(t, θ)
# ⎢       0          ℯ                                   0
# ⎢
# ⎢                               -t                               -t
# ⎢       0              0       ℯ  ⋅cos(Φ(t, θ))⋅sinh(W(t, θ)) + ℯ  ⋅cosh(W(t, θ))
# ⎢
# ⎢                                         -t                                          -t
# ⎣       0              0                 ℯ  ⋅sin(Φ(t, θ))⋅sinh(W(t, θ))            - ℯ  ⋅cos
#
#                                            ⎤
#                 0                          ⎥
#                                            ⎥
#                                            ⎥
#                 0                          ⎥
#                                            ⎥
#    -t                                      ⎥
#   ℯ  ⋅sin(Φ(t, θ))⋅sinh(W(t, θ))           ⎥
#                                            ⎥
#                            -t              ⎥
# ...

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("t theta x y")
t,theta,x,y = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
simplify(ch.tensor())
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢⎡∂                   ∂
# ⎢⎢──(A(t, θ)) + 1     ──(A(t, θ))
# ⎢⎢∂t                  ∂θ
# ⎢⎢
# ⎢⎢  ∂               -2⋅t ∂
# ⎢⎢  ──(A(t, θ))    ℯ    ⋅──(A(t, θ))
# ⎢⎢  ∂θ                   ∂t
# ⎢⎢
# ⎢⎢                                     ⎛                           ∂
# ⎢⎢                                    -⎜sin(Φ(t, θ))⋅sinh(W(t, θ))⋅──(Φ(t, θ)) + cos(Φ(t, θ)
# ⎢⎢                                     ⎝                           ∂t
# ⎢⎢       0                 0          ──────────────────────────────────────────────────────
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                          ⎛
# ⎢⎢                                                          ⎜-sin(Φ(t, θ))⋅sinh(W(t, θ)) + s
# ⎢⎢                                                          ⎝
# ⎢⎢       0                 0                                ────────────────────────────────
# ⎢⎣
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#
#
#
#
#                                 0
#
#
#
#                                 0
#
#
# ...

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()

# %%
#  rm1 = RiemannCurvatureTensor.from_christoffels(ch)
#  rm1.tensor()

# %%
#  weyl = WeylTensor.from_metric(metric)
#  weyl.tensor()

# %%
ricciSimplified = simplify(Ric.tensor())
ricciSimplified

# %%
einsteinSimplified = simplify(einst.tensor())
einsteinSimplified
