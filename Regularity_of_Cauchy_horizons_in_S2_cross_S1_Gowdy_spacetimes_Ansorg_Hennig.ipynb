# %% [markdown]
# #  Regularity of Cauchy horizons in S2 × S1 Gowdy spacetimes by Ansorg and Hennig
# ##  Geoff Cope
# ##  Univeristy of Utah
# ##  𐐏𐐭𐑌𐐲𐑂𐐲𐑉𐑅𐐮𐐻𐐨 𐐲𐑂 𐐏𐐭𐐻𐐫
# ##  January 16, 2022

# %% [markdown]
# https://arxiv.org/abs/0911.1000

# %% [markdown]
# What needs to be done is transformation with the u equation 4

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
t,theta,phi,delta,dt,dtheta,dphi,ddelta = symbols('t theta phi delta dt dtheta dphi ddelta')

# %%
M = Function('M')(t,theta)
M
# Out:
# M(t, θ)

# %%
Q = Function('Q')(t,theta)
Q
# Out:
# Q(t, θ)

# %%
u = Function('u')(t,theta)
u
# Out:
# u(t, θ)

# %%
variables = Matrix([t,theta,phi,delta])
variables
# Out:
# ⎡t⎤
# ⎢ ⎥
# ⎢θ⎥
# ⎢ ⎥
# ⎢φ⎥
# ⎢ ⎥
# ⎣δ⎦

# %%
differentials = Matrix([dt,dtheta,dphi,ddelta])
differentials
# Out:
# ⎡  dt  ⎤
# ⎢      ⎥
# ⎢dtheta⎥
# ⎢      ⎥
# ⎢ dphi ⎥
# ⎢      ⎥
# ⎣ddelta⎦

# %%
lineElement = expand( exp(M) * (-dt**2 + dtheta**2) + exp(u) * sin(theta)**2 * (dphi + Q * ddelta )**2 + exp(-u) * sin(t)**2 * ddelta**2 )  
lineElement
# Out:
#       2  2        u(t, θ)    2            2  -u(t, θ)    2                             u(t,
# ddelta ⋅Q (t, θ)⋅ℯ       ⋅sin (θ) + ddelta ⋅ℯ        ⋅sin (t) + 2⋅ddelta⋅dphi⋅Q(t, θ)⋅ℯ
#
# θ)    2          2  u(t, θ)    2        2  M(t, θ)         2  M(t, θ)
#   ⋅sin (θ) + dphi ⋅ℯ       ⋅sin (θ) - dt ⋅ℯ        + dtheta ⋅ℯ

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡  M(t, θ)
# ⎢-ℯ            0                 0                                    0
# ⎢
# ⎢            M(t, θ)
# ⎢    0      ℯ                    0                                    0
# ⎢
# ⎢                          u(t, θ)    2                            u(t, θ)    2
# ⎢    0         0          ℯ       ⋅sin (θ)                Q(t, θ)⋅ℯ       ⋅sin (θ)
# ⎢
# ⎢                              u(t, θ)    2      2        u(t, θ)    2       -u(t, θ)    2
# ⎣    0         0      Q(t, θ)⋅ℯ       ⋅sin (θ)  Q (t, θ)⋅ℯ       ⋅sin (θ) + ℯ        ⋅sin (t
#
#  ⎤
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
# )⎦

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡  M(t, θ)
# ⎢-ℯ            0                 0                                    0
# ⎢
# ⎢            M(t, θ)
# ⎢    0      ℯ                    0                                    0
# ⎢
# ⎢                          u(t, θ)    2                            u(t, θ)    2
# ⎢    0         0          ℯ       ⋅sin (θ)                Q(t, θ)⋅ℯ       ⋅sin (θ)
# ⎢
# ⎢                              u(t, θ)    2      2        u(t, θ)    2       -u(t, θ)    2
# ⎣    0         0      Q(t, θ)⋅ℯ       ⋅sin (θ)  Q (t, θ)⋅ℯ       ⋅sin (θ) + ℯ        ⋅sin (t
#
#  ⎤
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
#  ⎥
# )⎦

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("t theta phi delta")
t,theta,phi,delta = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
simplify(ch.tensor())
# Out:
# ⎡
# ⎢
# ⎢⎡∂            ∂
# ⎢⎢──(M(t, θ))  ──(M(t, θ))
# ⎢⎢∂t           ∂θ
# ⎢⎢───────────  ───────────                                 0
# ⎢⎢     2            2
# ⎢⎢
# ⎢⎢∂            ∂
# ⎢⎢──(M(t, θ))  ──(M(t, θ))
# ⎢⎢∂θ           ∂t
# ⎢⎢───────────  ───────────                                 0
# ⎢⎢     2            2
# ⎢⎢
# ⎢⎢                                       -M(t, θ) + u(t, θ)    2    ∂
# ⎢⎢                                      ℯ                  ⋅sin (θ)⋅──(u(t, θ))
# ⎢⎢                                                                  ∂t
# ⎢⎢     0            0                   ───────────────────────────────────────
# ⎢⎢                                                         2
# ⎢⎢
# ⎢⎢                          ⎛        ∂             ∂          ⎞  -M(t, θ) + u(t, θ)    2
# ⎢⎢                          ⎜Q(t, θ)⋅──(u(t, θ)) + ──(Q(t, θ))⎟⋅ℯ                  ⋅sin (θ)
# ⎢⎢                          ⎝        ∂t            ∂t         ⎠
# ...

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()
# Out:
# ⎡                                        2              2
# ⎢                                  2    ∂              ∂                          2
# ⎢   2⋅u(t, θ)    2    ⎛∂          ⎞    ───(M(t, θ))   ───(M(t, θ))   ⎛∂          ⎞        ∂
# ⎢  ℯ         ⋅sin (θ)⋅⎜──(Q(t, θ))⎟      2              2            ⎜──(u(t, θ))⎟        ──
# ⎢                     ⎝∂t         ⎠    ∂t             ∂θ             ⎝∂t         ⎠        ∂θ
# ⎢- ───────────────────────────────── - ──────────── + ──────────── - ────────────── + 1 + ──
# ⎢                   2                       2              2               2
# ⎢              2⋅sin (t)
# ⎢
# ⎢
# ⎢
# ⎢    2⋅u(t, θ)    2    ∂           ∂             ∂           ∂             ∂             ∂
# ⎢   ℯ         ⋅sin (θ)⋅──(Q(t, θ))⋅──(Q(t, θ))   ──(u(t, θ))⋅──(u(t, θ))   ──(M(t, θ))   ──(
# ⎢                      ∂t          ∂θ            ∂t          ∂θ            ∂t            ∂t
# ...

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/r6/p_thrggs57s55w7ct5svygzr0000gn/T/ipykernel_3719/1518504684.py in <module>
# ----> 1 R = RicciScalar.from_riccitensor(Ric)
#       2 R.simplify()
#       3 R.expr
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/ricci.py in from_riccitensor(cls, riccitensor, parent_metric)
#     230
#     231         if not riccitensor.config == "ul":
# --> 232             riccitensor = riccitensor.change_config(
#     233                 newconfig="ul", metric=parent_metric
#     234             )
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/ricci.py in change_config(self, newconfig, metric)
#     137         if metric is None:
#     138             raise Exception("Parent Metric not found, can't do configuration change")
# --> 139         new_tensor = _change_config(self, metric, newconfig)
# ...

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()

# %%
#  rm1 = RiemannCurvatureTensor.from_christoffels(ch)
#  rm1.tensor()

# %%
#  weyl = WeylTensor.from_metric(metric)
#  weyl.tensor()

# %%
ricciSimplified = simplify(Ric.tensor())
ricciSimplified

# %%
einsteinSimplified = simplify(einst.tensor())
einsteinSimplified
