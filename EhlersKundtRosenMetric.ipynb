# %% [markdown]
# # Colliding Plane Waves Metric
# #####  Geoff Cope
# #####  University of Utah
# #####  December 22, 2021

# %% [markdown]
# Where this metric is taken from:  "Interacting Gravitational, Electromagnetic, Neutrino and Other Waves" by Anzhong Wang page 44.  Christoffel Symbols are calculated on page 55.  This metric also appears in "Colliding Plane Waves In General Relativity" by Griffiths page 20 Equation 4.13

# %% [markdown]
# http://213.230.96.51:8090/files/ebooks/Fizika/Griffiths%20J.B.%20Colliding%20plane%20waves%20in%20general%20relativity%20(OUP,%201991)(ISBN%200198532091)(254s)%20PGr%20.pdf

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
u,v,x,y,du,dv,dx,dy = symbols('u v x y du dv dx dy')

# %%
M = Function('M')(u,v)
M
# Out:
# M(u, v)

# %%
U = Function('U')(u,v)
U
# Out:
# U(u, v)

# %%
V = Function('V')(u,v)
V
# Out:
# V(u, v)

# %%
W = Function('W')(u,v)
W
# Out:
# W(u, v)

# %%
variables = Matrix( [u,v,x,y] )
variables
# Out:
# ⎡u⎤
# ⎢ ⎥
# ⎢v⎥
# ⎢ ⎥
# ⎢x⎥
# ⎢ ⎥
# ⎣y⎦

# %%
differentials = Matrix( [du,dv,dx,dy] ) 
differentials
# Out:
# ⎡du⎤
# ⎢  ⎥
# ⎢dv⎥
# ⎢  ⎥
# ⎢dx⎥
# ⎢  ⎥
# ⎣dy⎦

# %%
lineElement = expand(2*exp(-M)*du*dv - exp(-U)* ( exp(V) * cosh(W) * dx**2 - 2*sinh(W)*dx*dy + exp(-V)*cosh(W)* dy**2))
lineElement
# Out:
#          -M(u, v)     2  -U(u, v)  V(u, v)                          -U(u, v)
# 2⋅du⋅dv⋅ℯ         - dx ⋅ℯ        ⋅ℯ       ⋅cosh(W(u, v)) + 2⋅dx⋅dy⋅ℯ        ⋅sinh(W(u, v)) -
#
#    2  -U(u, v)  -V(u, v)
#  dy ⋅ℯ        ⋅ℯ        ⋅cosh(W(u, v))

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡            -M(u, v)
# ⎢    0      ℯ                          0                                  0
# ⎢
# ⎢ -M(u, v)
# ⎢ℯ              0                      0                                  0
# ⎢
# ⎢                        -U(u, v)  V(u, v)                      -U(u, v)
# ⎢    0          0      -ℯ        ⋅ℯ       ⋅cosh(W(u, v))       ℯ        ⋅sinh(W(u, v))
# ⎢
# ⎢                            -U(u, v)                       -U(u, v)  -V(u, v)
# ⎣    0          0           ℯ        ⋅sinh(W(u, v))       -ℯ        ⋅ℯ        ⋅cosh(W(u, v))
#
# ⎤
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎦

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡            -M(u, v)
# ⎢    0      ℯ                          0                                  0
# ⎢
# ⎢ -M(u, v)
# ⎢ℯ              0                      0                                  0
# ⎢
# ⎢                        -U(u, v)  V(u, v)                      -U(u, v)
# ⎢    0          0      -ℯ        ⋅ℯ       ⋅cosh(W(u, v))       ℯ        ⋅sinh(W(u, v))
# ⎢
# ⎢                            -U(u, v)                       -U(u, v)  -V(u, v)
# ⎣    0          0           ℯ        ⋅sinh(W(u, v))       -ℯ        ⋅ℯ        ⋅cosh(W(u, v))
#
# ⎤
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎦

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("u v x y")
u,v,x,y = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
ch.tensor()
# Out:
# ⎡
# ⎢
# ⎢
# ⎢⎡ ∂
# ⎢⎢-──(M(u, v))  0
# ⎢⎢ ∂u
# ⎢⎢
# ⎢⎢     0        0
# ⎢⎢
# ⎢⎢                 ⎛ -U(u, v)  V(u, v)               ∂              -U(u, v)  V(u, v)
# ⎢⎢                 ⎜ℯ        ⋅ℯ       ⋅sinh(W(u, v))⋅──(W(u, v)) - ℯ        ⋅ℯ       ⋅cosh(W
# ⎢⎢                 ⎝                                 ∂v
# ⎢⎢     0        0  ─────────────────────────────────────────────────────────────────────────
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                 ⎛ -U(u, v)               ∂              -
# ⎢⎢                                                 ⎜ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) - ℯ
# ⎢⎢                                                 ⎝                        ∂v
# ⎢⎢     0        0                                  ─────────────────────────────────────────
# ⎢⎣
# ⎢
# ⎢
# ⎣
#
#
#
#
#
#  0
#
#
#  0
#
#         ∂              -U(u, v)  V(u, v)               ∂          ⎞  M(u, v)
# (u, v))⋅──(U(u, v)) + ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ
#         ∂v                                             ∂v         ⎠
# ────────────────────────────────────────────────────────────────────────────
#  2
#
# U(u, v)               ∂          ⎞  M(u, v)                                   ⎛ -U(u, v)  -V
#        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ                                          ⎜ℯ        ⋅ℯ
#                       ∂v         ⎠                                            ⎝
# ───────────────────────────────────────────                                   ──────────────
# 2
#
#
#
#
#
#
#
#
#                                                              0
#
#
#                                                              0
#
#                     ⎛ -U(u, v)               ∂              -U(u, v)               ∂
#                     ⎜ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) - ℯ        ⋅cosh(W(u, v))⋅──(W(u, v
#                     ⎝                        ∂v                                    ∂v
#                     ────────────────────────────────────────────────────────────────────────
#                                                              2
#
# (u, v)               ∂              -U(u, v)  -V(u, v)               ∂              -U(u, v)
#       ⋅sinh(W(u, v))⋅──(W(u, v)) - ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) - ℯ
#                      ∂v                                              ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                              2
#
#
#
#
#
#
#
#                                               ⎤  ⎡0       0
#                                               ⎥  ⎢
#                                               ⎥  ⎢    ∂
#                                               ⎥  ⎢0  -──(M(u, v))
#                                               ⎥  ⎢    ∂v
#                                               ⎥  ⎢
#   ⎞  M(u, v)                                  ⎥  ⎢                 ⎛ -U(u, v)  V(u, v)
# ))⎟⋅ℯ                                         ⎥  ⎢                 ⎜ℯ        ⋅ℯ       ⋅sinh(
#   ⎠                                           ⎥  ⎢                 ⎝
# ────────────                                  ⎥  ⎢0       0        ─────────────────────────
#                                               ⎥  ⎢
#                                               ⎥  ⎢
#   -V(u, v)               ∂          ⎞  M(u, v)⎥  ⎢
# ⋅ℯ        ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ       ⎥  ⎢
#                          ∂v         ⎠         ⎥  ⎢
# ──────────────────────────────────────────────⎥  ⎢0       0
#                                               ⎦  ⎣
#
#
#
#
#
#
#
#                                                  0
#
#
#                                                  0
#
#
#          ∂              -U(u, v)  V(u, v)               ∂              -U(u, v)  V(u, v)
# W(u, v))⋅──(W(u, v)) - ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅ℯ       ⋅cos
#          ∂u                                             ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                  2
#
#        ⎛ -U(u, v)               ∂              -U(u, v)               ∂          ⎞  M(u, v)
#        ⎜ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) - ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ
#        ⎝                        ∂u                                    ∂u         ⎠
#        ────────────────────────────────────────────────────────────────────────────────────
#                                                 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#            ∂          ⎞  M(u, v)                                    ⎛ -U(u, v)
# h(W(u, v))⋅──(V(u, v))⎟⋅ℯ                                           ⎜ℯ        ⋅sinh(W(u, v))
#            ∂u         ⎠                                             ⎝
# ────────────────────────────────                                    ────────────────────────
#
#
#                                   ⎛ -U(u, v)  -V(u, v)               ∂              -U(u, v)
#                                   ⎜ℯ        ⋅ℯ        ⋅sinh(W(u, v))⋅──(W(u, v)) - ℯ
#                                   ⎝                                  ∂u
#                                   ──────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                  0
#
#
#                  0
#
#
#  ∂              -U(u, v)               ∂          ⎞  M(u, v)
# ⋅──(U(u, v)) - ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ
#  ∂u                                    ∂u         ⎠
# ────────────────────────────────────────────────────────────
#                  2
#
#   -V(u, v)               ∂              -U(u, v)  -V(u, v)               ∂          ⎞  M(u,
# ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) - ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ
#                          ∂u                                              ∂u         ⎠
# ────────────────────────────────────────────────────────────────────────────────────────────
#                  2
#
#
#
#
#      ⎡
#      ⎢
#      ⎢
#   ⎤  ⎢
#   ⎥  ⎢
#   ⎥  ⎢
#   ⎥  ⎢
#   ⎥  ⎢
#   ⎥  ⎢
#   ⎥  ⎢
#   ⎥  ⎢
#   ⎥  ⎢
#   ⎥  ⎢  ⎛   -U(u, v)               ∂              -U(u, v)               ∂          ⎞  U(u,
#   ⎥  ⎢  ⎜- ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ
#   ⎥  ⎢  ⎝                          ∂u                                    ∂u         ⎠
# v)⎥  ⎢- ────────────────────────────────────────────────────────────────────────────────────
#   ⎥  ⎢                                                   2
#   ⎥  ⎢
# ──⎥  ⎢⎛   -U(u, v)               ∂              -U(u, v)               ∂          ⎞ ⎛   U(u,
#   ⎦  ⎢⎜- ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅⎝- ℯ
#      ⎢⎝                          ∂u                                    ∂u         ⎠
#      ⎢──────────────────────────────────────────────────────────────────────────────────────
#      ⎣                                                            2⋅cosh(W(u, v))
#
#
#
#
#                                                                    0
#
#
#
#
#
#                                                                    0
#
#
# v)                 ⎛   U(u, v)  -V(u, v)     2             U(u, v)  -V(u, v)⎞ ⎛   -U(u, v)
#   ⋅sinh(W(u, v))   ⎝- ℯ       ⋅ℯ        ⋅sinh (W(u, v)) - ℯ       ⋅ℯ        ⎠⋅⎜- ℯ        ⋅ℯ
#                                                                               ⎝
# ──────────────── + ─────────────────────────────────────────────────────────────────────────
#
#
#  v)  -V(u, v)     2             U(u, v)  -V(u, v)⎞   ⎛   -U(u, v)  -V(u, v)               ∂
#    ⋅ℯ        ⋅sinh (W(u, v)) - ℯ       ⋅ℯ        ⎠   ⎜- ℯ        ⋅ℯ        ⋅sinh(W(u, v))⋅──
#                                                      ⎝                                    ∂u
# ────────────────────────────────────────────────── - ───────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# V(u, v)               ∂              -U(u, v)  V(u, v)               ∂              -U(u, v)
#        ⋅sinh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(U(u, v)) - ℯ
#                       ∂u                                             ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                     2⋅cosh(W(u, v))
#
#              -U(u, v)  -V(u, v)               ∂              -U(u, v)  -V(u, v)
# (W(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W(u, v)
#                                               ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                             2
#
#
#
#
#
#
#
#
#
#
#
#
#
#   V(u, v)               ∂          ⎞     ⎛   -U(u, v)               ∂              -U(u, v)
# ⋅ℯ       ⋅cosh(W(u, v))⋅──(V(u, v))⎟     ⎜- ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅
#                         ∂u         ⎠     ⎝                          ∂v
# ────────────────────────────────────   - ───────────────────────────────────────────────────
#                                                                                           2
#
#   ∂          ⎞  U(u, v)                ⎛   -U(u, v)               ∂              -U(u, v)
# )⋅──(V(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))  ⎜- ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅co
#   ∂u         ⎠                         ⎝                          ∂v
# ─────────────────────────────────────  ─────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               ∂          ⎞  U(u, v)                 ⎛   U(u, v)  -V(u, v)     2
# cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))   ⎝- ℯ       ⋅ℯ        ⋅sinh (W(u, v)) - ℯ
#               ∂v         ⎠
# ───────────────────────────────────────────────── + ────────────────────────────────────────
#
#
#             ∂          ⎞ ⎛   U(u, v)  -V(u, v)     2             U(u, v)  -V(u, v)⎞   ⎛   -U
# sh(W(u, v))⋅──(W(u, v))⎟⋅⎝- ℯ       ⋅ℯ        ⋅sinh (W(u, v)) - ℯ       ⋅ℯ        ⎠   ⎜- ℯ
#             ∂v         ⎠                                                              ⎝
# ─────────────────────────────────────────────────────────────────────────────────── - ──────
#        2⋅cosh(W(u, v))
#
#
#
#
#         0
#
#
#
#
#
#         0
#
#
# U(u, v)  -V(u, v)⎞ ⎛   -U(u, v)  V(u, v)               ∂              -U(u, v)  V(u, v)
#        ⋅ℯ        ⎠⋅⎜- ℯ        ⋅ℯ       ⋅sinh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ       ⋅cosh
#                    ⎝                                   ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                      2⋅cosh(W(u, v))
#
# (u, v)  -V(u, v)               ∂              -U(u, v)  -V(u, v)               ∂
#       ⋅ℯ        ⋅sinh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) +
#                                ∂v                                              ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                              2
#
#                                                                           ⎛   -U(u, v)
#                                                                           ⎜- ℯ        ⋅sinh(
#                                                                           ⎝
#                                                                         - ──────────────────
#
#
#                                                                           ⎛   -U(u, v)
#                                                                           ⎜- ℯ        ⋅sinh(
#                                                                           ⎝
#                                                                         - ──────────────────
#
#
#           ∂              -U(u, v)  V(u, v)               ∂          ⎞
# (W(u, v))⋅──(U(u, v)) - ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(V(u, v))⎟
#           ∂v                                             ∂v         ⎠
# ─────────────────────────────────────────────────────────────────────
#
#
#   -U(u, v)  -V(u, v)               ∂          ⎞  U(u, v)
#  ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))
#                                    ∂v         ⎠
# ──────────────────────────────────────────────────────────────────────
#
#
#          ∂              -U(u, v)               ∂          ⎞  U(u, v)                 ⎛   U(u
# W(u, v))⋅──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))   ⎝- ℯ
#          ∂u                                    ∂u         ⎠
# ────────────────────────────────────────────────────────────────────────────────── + ───────
#                                2
#
#          ∂              -U(u, v)               ∂          ⎞  U(u, v)                 ⎛   U(u
# W(u, v))⋅──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))   ⎝- ℯ
#          ∂v                                    ∂v         ⎠
# ────────────────────────────────────────────────────────────────────────────────── + ───────
#                                2
#
#
#
#
#
#
#
#
#
#
#
#
#
# , v)  -V(u, v)     2             U(u, v)  -V(u, v)⎞ ⎛   -U(u, v)  V(u, v)               ∂
#     ⋅ℯ        ⋅sinh (W(u, v)) - ℯ       ⋅ℯ        ⎠⋅⎜- ℯ        ⋅ℯ       ⋅sinh(W(u, v))⋅──(W
#                                                     ⎝                                   ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                       2⋅cosh
#
# , v)  -V(u, v)     2             U(u, v)  -V(u, v)⎞ ⎛   -U(u, v)  V(u, v)               ∂
#     ⋅ℯ        ⋅sinh (W(u, v)) - ℯ       ⋅ℯ        ⎠⋅⎜- ℯ        ⋅ℯ       ⋅sinh(W(u, v))⋅──(W
#                                                     ⎝                                   ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                       2⋅cosh
#
#
#
#
#                                         0
#
#
#
#
#
#                                         0
#
#
#            -U(u, v)  V(u, v)               ∂              -U(u, v)  V(u, v)               ∂
# (u, v)) + ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(U(u, v)) - ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──
#                                            ∂u                                             ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
# (W(u, v))
#
#            -U(u, v)  V(u, v)               ∂              -U(u, v)  V(u, v)               ∂
# (u, v)) + ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(U(u, v)) - ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──
#                                            ∂v                                             ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
# (W(u, v))
#
#
#
#
#
#
#
#
#
#
#
#
#
#          ⎞  ⎛   -U(u, v)               ∂              -U(u, v)               ∂          ⎞ ⎛
# (V(u, v))⎟  ⎜- ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅⎝-
#          ⎠  ⎝                          ∂u                                    ∂u         ⎠
# ──────────  ────────────────────────────────────────────────────────────────────────────────
#                                                                         2⋅cosh(W(u, v))
#
#          ⎞  ⎛   -U(u, v)               ∂              -U(u, v)               ∂          ⎞ ⎛
# (V(u, v))⎟  ⎜- ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅⎝-
#          ⎠  ⎝                          ∂v                                    ∂v         ⎠
# ──────────  ────────────────────────────────────────────────────────────────────────────────
#                                                                         2⋅cosh(W(u, v))
#
#
#
#
#
#
#
#
#
#
#
#
#
#   U(u, v)  -V(u, v)     2             U(u, v)  -V(u, v)⎞   ⎛   -U(u, v)  -V(u, v)
#  ℯ       ⋅ℯ        ⋅sinh (W(u, v)) - ℯ       ⋅ℯ        ⎠   ⎜- ℯ        ⋅ℯ        ⋅sinh(W(u,
#                                                            ⎝
# ──────────────────────────────────────────────────────── - ─────────────────────────────────
#
#
#   U(u, v)  -V(u, v)     2             U(u, v)  -V(u, v)⎞   ⎛   -U(u, v)  -V(u, v)
#  ℯ       ⋅ℯ        ⋅sinh (W(u, v)) - ℯ       ⋅ℯ        ⎠   ⎜- ℯ        ⋅ℯ        ⋅sinh(W(u,
#                                                            ⎝
# ──────────────────────────────────────────────────────── - ─────────────────────────────────
#
#
#
#
#
#                                                                          0
#
#
#
#
#
#                                                                          0
#
#
#     ∂              -U(u, v)  -V(u, v)               ∂              -U(u, v)  -V(u, v)
# v))⋅──(W(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W
#     ∂u                                              ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                   2
#
#     ∂              -U(u, v)  -V(u, v)               ∂              -U(u, v)  -V(u, v)
# v))⋅──(W(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W
#     ∂v                                              ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                   2
#
#
#
#
#
#
#
#
#
#
#
#
#
#         ∂          ⎞  U(u, v)              ⎤  ⎡
# (u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))⎥  ⎢
#         ∂u         ⎠                       ⎥  ⎢
# ───────────────────────────────────────────⎥  ⎢
#                                            ⎥  ⎢
#                                            ⎥  ⎢
#         ∂          ⎞  U(u, v)              ⎥  ⎢
# (u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))⎥  ⎢
#         ∂v         ⎠                       ⎥  ⎢
# ───────────────────────────────────────────⎥  ⎢
#                                            ⎥  ⎢
#                                            ⎥  ⎢
#                                            ⎥  ⎢   ⎛   -U(u, v)               ∂
#                                            ⎥  ⎢   ⎜- ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) + ℯ
#                                            ⎥  ⎢   ⎝                          ∂u
#                                            ⎥  ⎢ - ──────────────────────────────────────────
#                                            ⎥  ⎢
#                                            ⎥  ⎢
#                                            ⎥  ⎢  ⎛   -U(u, v)               ∂              -
#                                            ⎥  ⎢  ⎜- ℯ        ⋅sinh(W(u, v))⋅──(U(u, v)) + ℯ
#                                            ⎥  ⎢  ⎝                          ∂u
#                                            ⎥  ⎢- ───────────────────────────────────────────
#                                            ⎦  ⎣
#
#
#
#
#
#
#
#
#
#
#
#
#
# -U(u, v)               ∂          ⎞  U(u, v)  V(u, v)                 ⎛   -U(u, v)  V(u, v)
#         ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅ℯ       ⋅cosh(W(u, v))   ⎜- ℯ        ⋅ℯ       ⋅
#                        ∂u         ⎠                                   ⎝
# ─────────────────────────────────────────────────────────────────── - ──────────────────────
#             2
#
# U(u, v)               ∂          ⎞  U(u, v)                 ⎛   -U(u, v)  -V(u, v)
#        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))   ⎜- ℯ        ⋅ℯ        ⋅sinh(W(u,
#                       ∂u         ⎠                          ⎝
# ───────────────────────────────────────────────────────── - ────────────────────────────────
#       2
#
#
#
#
#    0
#
#
#
#
#
# ...
#            0
#
#
# V(u, v)               ∂              -U(u, v)  V(u, v)               ∂              -U(u, v)
#        ⋅sinh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(U(u, v)) - ℯ
#                       ∂v                                             ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                     2
#
#              ∂              -U(u, v)  -V(u, v)               ∂              -U(u, v)  -V(u,
# inh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) + ℯ        ⋅ℯ
#              ∂v                                              ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                 2
#
#                                                                  ⎛   -U(u, v)
#                                                                  ⎜- ℯ        ⋅sinh(W(u, v))⋅
#                                                                  ⎝
#                                                                - ───────────────────────────
#
#
#                                                                  ⎛   -U(u, v)
#                                                                  ⎜- ℯ        ⋅sinh(W(u, v))⋅
#                                                                  ⎝
#                                                                - ───────────────────────────
#
#
#   V(u, v)               ∂          ⎞  U(u, v)
# ⋅ℯ       ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))
#                         ∂v         ⎠
# ───────────────────────────────────────────────────────────
#
#
# v)               ∂          ⎞  U(u, v)  V(u, v)
#   ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅ℯ       ⋅cosh(W(u, v))
#                  ∂v         ⎠
# ─────────────────────────────────────────────────────────────
#
#
# ∂              -U(u, v)               ∂          ⎞  U(u, v)  V(u, v)                 ⎛   -U(
# ──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅ℯ       ⋅cosh(W(u, v))   ⎜- ℯ
# ∂u                                    ∂u         ⎠                                   ⎝
# ────────────────────────────────────────────────────────────────────────────────── - ───────
#                            2
#
# ∂              -U(u, v)               ∂          ⎞  U(u, v)  V(u, v)                 ⎛   -U(
# ──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅ℯ       ⋅cosh(W(u, v))   ⎜- ℯ
# ∂v                                    ∂v         ⎠                                   ⎝
# ────────────────────────────────────────────────────────────────────────────────── - ───────
#                            2
#
#
#
#
#
#
#
#
#
#
#
#
#
# u, v)  V(u, v)               ∂              -U(u, v)  V(u, v)               ∂              -
#      ⋅ℯ       ⋅sinh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(U(u, v)) - ℯ
#                              ∂u                                             ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                            2
#
# u, v)  V(u, v)               ∂              -U(u, v)  V(u, v)               ∂              -
#      ⋅ℯ       ⋅sinh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ       ⋅cosh(W(u, v))⋅──(U(u, v)) - ℯ
#                              ∂v                                             ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                            2
#
#
#
#
#                   0
#
#
#
#
#
#                   0
#
#
# U(u, v)  V(u, v)               ∂          ⎞  U(u, v)                  ⎛   -U(u, v)
#        ⋅ℯ       ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))    ⎜- ℯ        ⋅sinh(W(u,
#                                ∂u         ⎠                           ⎝
# ──────────────────────────────────────────────────────────────────  - ──────────────────────
#
#
# U(u, v)  V(u, v)               ∂          ⎞  U(u, v)                  ⎛   -U(u, v)
#        ⋅ℯ       ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))    ⎜- ℯ        ⋅sinh(W(u,
#                                ∂v         ⎠                           ⎝
# ──────────────────────────────────────────────────────────────────  - ──────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ∂              -U(u, v)               ∂          ⎞  U(u, v)                 ⎛   -U(u, v
#  v))⋅──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))   ⎜- ℯ
#      ∂u                                    ∂u         ⎠                          ⎝
# ────────────────────────────────────────────────────────────────────────────── - ───────────
#                            2
#
#      ∂              -U(u, v)               ∂          ⎞  U(u, v)                 ⎛   -U(u, v
#  v))⋅──(U(u, v)) + ℯ        ⋅cosh(W(u, v))⋅──(W(u, v))⎟⋅ℯ       ⋅sinh(W(u, v))   ⎜- ℯ
#      ∂v                                    ∂v         ⎠                          ⎝
# ────────────────────────────────────────────────────────────────────────────── - ───────────
#                            2
#
#
#
#
#
#
#
#
#
#
#
#
#
# )  -V(u, v)               ∂              -U(u, v)  -V(u, v)               ∂              -U(
#  ⋅ℯ        ⋅sinh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) + ℯ
#                           ∂u                                              ∂u
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                              2
#
# )  -V(u, v)               ∂              -U(u, v)  -V(u, v)               ∂              -U(
#  ⋅ℯ        ⋅sinh(W(u, v))⋅──(W(u, v)) + ℯ        ⋅ℯ        ⋅cosh(W(u, v))⋅──(U(u, v)) + ℯ
#                           ∂v                                              ∂v
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                              2
#
#
#
#
#                         0
#
#
#
#
#
#                         0
#
#
# u, v)  -V(u, v)               ∂          ⎞  U(u, v)  V(u, v)              ⎤⎤
#      ⋅ℯ        ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅ℯ       ⋅cosh(W(u, v))⎥⎥
#                               ∂u         ⎠                                ⎥⎥
# ──────────────────────────────────────────────────────────────────────────⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
# u, v)  -V(u, v)               ∂          ⎞  U(u, v)  V(u, v)              ⎥⎥
#      ⋅ℯ        ⋅cosh(W(u, v))⋅──(V(u, v))⎟⋅ℯ       ⋅ℯ       ⋅cosh(W(u, v))⎥⎥
#                               ∂v         ⎠                                ⎥⎥
# ──────────────────────────────────────────────────────────────────────────⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎥⎥
#                                                                           ⎦⎦

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/r6/p_thrggs57s55w7ct5svygzr0000gn/T/ipykernel_18181/286807235.py in <module>
# ----> 1 Ric = RicciTensor.from_metric(metric)
#       2 Ric.tensor()
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/ricci.py in from_metric(cls, metric)
#     107         """
#     108         ch = ChristoffelSymbols.from_metric(metric)
# --> 109         return cls.from_christoffels(ch, parent_metric=None)
#     110
#     111     def change_config(self, newconfig="ul", metric=None):
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/ricci.py in from_christoffels(cls, chris, parent_metric)
#      90
#      91         """
# ---> 92         rt = RiemannCurvatureTensor.from_christoffels(
#      93             chris, parent_metric=parent_metric
#      94         )
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/riemann.py in from_christoffels(cls, chris, parent_metric)
#      88             for p in range(dims):
#      89                 temp += arr[p, s, n] * arr[t, p, r] - arr[p, s, r] * arr[t, p, n]
# ---> 90             riemann_list[t][s][r][n] = sympy.simplify(temp)
#      91         if parent_metric is None:
#      92             parent_metric = chris.parent_metric
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     694
#     695     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 696         expr = trigsimp(expr, deep=True)
#     697
#     698     if expr.has(log):
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     508                    }[method]
#     509
# --> 510     return trigsimpfunc(expr)
#     511
#     512
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#     501     trigsimpfunc = {
#     502         'fu': (lambda x: fu(x, **opts)),
# --> 503         'matching': (lambda x: futrig(x)),
#     504         'groebner': (lambda x: groebnersimp(x, **opts)),
#     505         'combined': (lambda x: futrig(groebnersimp(x,
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/trigsimp.py in futrig(e, hyper, **kwargs)
#    1104     if hyper and e.has(HyperbolicFunction):
#    1105         e, f = hyper_as_trig(e)
# -> 1106         e = f(bottom_up(e, _futrig))
#    1107
#    1108     if e != old and e.is_Mul and e.args[0].is_Rational:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/fu.py in <lambda>(x)
#    2073     d = Dummy()
#    2074
# -> 2075     return _osborne(masked, d), lambda x: collect(signsimp(
#    2076         _osbornei(x, d).xreplace(dict(reps))), S.ImaginaryUnit)
#    2077
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     173         reps = dict(zip(nonsyms, [Dummy(**assumptions(i)) for i in nonsyms]))
#     174         syms = [reps.get(s, s) for s in syms]
# --> 175         rv = collect(expr.subs(reps), syms,
#     176             func=func, evaluate=evaluate, exact=exact,
#     177             distribute_order_term=distribute_order_term)
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     362                     for a in expr.args if a != o]) + o
#     363         elif expr.is_Mul:
# --> 364             return expr.func(*[
#     365                 collect(term, syms, func, True, exact, distribute_order_term)
#     366                 for term in expr.args])
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in <listcomp>(.0)
#     363         elif expr.is_Mul:
#     364             return expr.func(*[
# --> 365                 collect(term, syms, func, True, exact, distribute_order_term)
#     366                 for term in expr.args])
#     367         elif expr.is_Pow:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     358         if expr.is_Add:
#     359             o = expr.getO() or 0
# --> 360             expr = expr.func(*[
#     361                     collect(a, syms, func, True, exact, distribute_order_term)
#     362                     for a in expr.args if a != o]) + o
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in <listcomp>(.0)
#     359             o = expr.getO() or 0
#     360             expr = expr.func(*[
# --> 361                     collect(a, syms, func, True, exact, distribute_order_term)
#     362                     for a in expr.args if a != o]) + o
#     363         elif expr.is_Mul:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     362                     for a in expr.args if a != o]) + o
#     363         elif expr.is_Mul:
# --> 364             return expr.func(*[
#     365                 collect(term, syms, func, True, exact, distribute_order_term)
#     366                 for term in expr.args])
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in <listcomp>(.0)
#     363         elif expr.is_Mul:
#     364             return expr.func(*[
# --> 365                 collect(term, syms, func, True, exact, distribute_order_term)
#     366                 for term in expr.args])
#     367         elif expr.is_Pow:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     389         c, nc = product.args_cnc(split_1=False)
#     390         args = list(ordered(c)) + nc
# --> 391         terms = [parse_term(i) for i in args]
#     392         small_first = True
#     393
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in <listcomp>(.0)
#     389         c, nc = product.args_cnc(split_1=False)
#     390         args = list(ordered(c)) + nc
# --> 391         terms = [parse_term(i) for i in args]
#     392         small_first = True
#     393
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in parse_term(expr)
#     279                 sexpr, rat_expo = exp(tail), coeff
#     280         elif isinstance(expr, Derivative):
# --> 281             sexpr, deriv = parse_derivative(expr)
#     282
#     283         return sexpr, rat_expo, sym_expo, deriv
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in parse_derivative(deriv)
#     215                 order += 1
#     216             else:
# --> 217                 raise NotImplementedError(
#     218                     'Improve MV Derivative support in collect')
#     219
#
# NotImplementedError: Improve MV Derivative support in collect

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/r6/p_thrggs57s55w7ct5svygzr0000gn/T/ipykernel_18181/3510081866.py in <module>
# ----> 1 einst = EinsteinTensor.from_metric(metric)
#       2 einst.tensor()
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/einstein.py in from_metric(cls, metric)
#      50     @classmethod
#      51     def from_metric(cls, metric):
# ---> 52         t_ricci = RicciTensor.from_metric(metric)
#      53         r_scalar = RicciScalar.from_riccitensor(t_ricci, t_ricci.parent_metric)
#      54         einstein_tensor = (
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/ricci.py in from_metric(cls, metric)
#     107         """
#     108         ch = ChristoffelSymbols.from_metric(metric)
# --> 109         return cls.from_christoffels(ch, parent_metric=None)
#     110
#     111     def change_config(self, newconfig="ul", metric=None):
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/ricci.py in from_christoffels(cls, chris, parent_metric)
#      90
#      91         """
# ---> 92         rt = RiemannCurvatureTensor.from_christoffels(
#      93             chris, parent_metric=parent_metric
#      94         )
#
# /opt/anaconda3/lib/python3.8/site-packages/einsteinpy/symbolic/riemann.py in from_christoffels(cls, chris, parent_metric)
#      88             for p in range(dims):
#      89                 temp += arr[p, s, n] * arr[t, p, r] - arr[p, s, r] * arr[t, p, n]
# ---> 90             riemann_list[t][s][r][n] = sympy.simplify(temp)
#      91         if parent_metric is None:
#      92             parent_metric = chris.parent_metric
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     694
#     695     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 696         expr = trigsimp(expr, deep=True)
#     697
#     698     if expr.has(log):
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     508                    }[method]
#     509
# --> 510     return trigsimpfunc(expr)
#     511
#     512
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#     501     trigsimpfunc = {
#     502         'fu': (lambda x: fu(x, **opts)),
# --> 503         'matching': (lambda x: futrig(x)),
#     504         'groebner': (lambda x: groebnersimp(x, **opts)),
#     505         'combined': (lambda x: futrig(groebnersimp(x,
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/trigsimp.py in futrig(e, hyper, **kwargs)
#    1104     if hyper and e.has(HyperbolicFunction):
#    1105         e, f = hyper_as_trig(e)
# -> 1106         e = f(bottom_up(e, _futrig))
#    1107
#    1108     if e != old and e.is_Mul and e.args[0].is_Rational:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/fu.py in <lambda>(x)
#    2073     d = Dummy()
#    2074
# -> 2075     return _osborne(masked, d), lambda x: collect(signsimp(
#    2076         _osbornei(x, d).xreplace(dict(reps))), S.ImaginaryUnit)
#    2077
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     173         reps = dict(zip(nonsyms, [Dummy(**assumptions(i)) for i in nonsyms]))
#     174         syms = [reps.get(s, s) for s in syms]
# --> 175         rv = collect(expr.subs(reps), syms,
#     176             func=func, evaluate=evaluate, exact=exact,
#     177             distribute_order_term=distribute_order_term)
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     362                     for a in expr.args if a != o]) + o
#     363         elif expr.is_Mul:
# --> 364             return expr.func(*[
#     365                 collect(term, syms, func, True, exact, distribute_order_term)
#     366                 for term in expr.args])
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in <listcomp>(.0)
#     363         elif expr.is_Mul:
#     364             return expr.func(*[
# --> 365                 collect(term, syms, func, True, exact, distribute_order_term)
#     366                 for term in expr.args])
#     367         elif expr.is_Pow:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     358         if expr.is_Add:
#     359             o = expr.getO() or 0
# --> 360             expr = expr.func(*[
#     361                     collect(a, syms, func, True, exact, distribute_order_term)
#     362                     for a in expr.args if a != o]) + o
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in <listcomp>(.0)
#     359             o = expr.getO() or 0
#     360             expr = expr.func(*[
# --> 361                     collect(a, syms, func, True, exact, distribute_order_term)
#     362                     for a in expr.args if a != o]) + o
#     363         elif expr.is_Mul:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     362                     for a in expr.args if a != o]) + o
#     363         elif expr.is_Mul:
# --> 364             return expr.func(*[
#     365                 collect(term, syms, func, True, exact, distribute_order_term)
#     366                 for term in expr.args])
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in <listcomp>(.0)
#     363         elif expr.is_Mul:
#     364             return expr.func(*[
# --> 365                 collect(term, syms, func, True, exact, distribute_order_term)
#     366                 for term in expr.args])
#     367         elif expr.is_Pow:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     389         c, nc = product.args_cnc(split_1=False)
#     390         args = list(ordered(c)) + nc
# --> 391         terms = [parse_term(i) for i in args]
#     392         small_first = True
#     393
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in <listcomp>(.0)
#     389         c, nc = product.args_cnc(split_1=False)
#     390         args = list(ordered(c)) + nc
# --> 391         terms = [parse_term(i) for i in args]
#     392         small_first = True
#     393
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in parse_term(expr)
#     279                 sexpr, rat_expo = exp(tail), coeff
#     280         elif isinstance(expr, Derivative):
# --> 281             sexpr, deriv = parse_derivative(expr)
#     282
#     283         return sexpr, rat_expo, sym_expo, deriv
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/simplify/radsimp.py in parse_derivative(deriv)
#     215                 order += 1
#     216             else:
# --> 217                 raise NotImplementedError(
#     218                     'Improve MV Derivative support in collect')
#     219
#
# NotImplementedError: Improve MV Derivative support in collect

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/r6/p_thrggs57s55w7ct5svygzr0000gn/T/ipykernel_18181/1518504684.py in <module>
# ----> 1 R = RicciScalar.from_riccitensor(Ric)
#       2 R.simplify()
#       3 R.expr
#
# NameError: name 'Ric' is not defined

# %%
rm1 = RiemannCurvatureTensor.from_christoffels(ch)
rm1.tensor()

# %%
weyl = WeylTensor.from_metric(metric)
weyl.tensor()
