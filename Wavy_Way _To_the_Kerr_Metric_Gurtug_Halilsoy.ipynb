# %% [markdown]
# # Wavy Way To the Kerr Metric by Gurtug and Halilsoy
# ##  Geoff Cope
# ##  Univeristy of Utah
# ##  December 29, 2021

# %% [markdown]
# There are a number of different interesting metrics in this paper and here we concentrate on the first one which is the Weyl Papetrou form for a rotating axially symmetric field.  See also the notebook on the Ernst equation derivation.  Also see Big Bang in T3 Gowdy Cosmological Models by Quevedo equation 11.

# %% [markdown]
# https://arxiv.org/abs/1509.05174

# %% [markdown]
# https://arxiv.org/abs/gr-qc/0103113

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
t,rho,phi,z,dt,drho,dphi,dz = symbols('t rho phi z dt drho dphi dz')

# %%
f = Function('f')(rho,z)
f
# Out:
# f(ρ, z)

# %%
omega = Function('omega')(rho,z)
omega
# Out:
# ω(ρ, z)

# %%
gamma = Function('gamma')(rho,z)
gamma
# Out:
# γ(ρ, z)

# %%
variables = Matrix([t,rho,phi,z])
variables
# Out:
# ⎡t⎤
# ⎢ ⎥
# ⎢ρ⎥
# ⎢ ⎥
# ⎢φ⎥
# ⎢ ⎥
# ⎣z⎦

# %%
differentials = Matrix([dt,drho,dphi,dz])
differentials
# Out:
# ⎡ dt ⎤
# ⎢    ⎥
# ⎢drho⎥
# ⎢    ⎥
# ⎢dphi⎥
# ⎢    ⎥
# ⎣ dz ⎦

# %%
lineElement = expand( f**-1 * ( (exp(2*gamma) * (dz**2 + drho**2) + rho**2 * dphi**2)) - f*(dt - omega * dphi)**2 ) 
lineElement
# Out:
#     2  2                                                            2  2⋅γ(ρ, z)
# dphi ⋅ρ        2          2                                     drho ⋅ℯ              2
# ──────── - dphi ⋅f(ρ, z)⋅ω (ρ, z) + 2⋅dphi⋅dt⋅f(ρ, z)⋅ω(ρ, z) + ──────────────── - dt ⋅f(ρ,
# f(ρ, z)                                                             f(ρ, z)
#
#        2  2⋅γ(ρ, z)
#      dz ⋅ℯ
# z) + ──────────────
#         f(ρ, z)

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡   -f(ρ, z)          0            f(ρ, z)⋅ω(ρ, z)            0     ⎤
# ⎢                                                                   ⎥
# ⎢                  2⋅γ(ρ, z)                                        ⎥
# ⎢                 ℯ                                                 ⎥
# ⎢       0         ──────────              0                   0     ⎥
# ⎢                  f(ρ, z)                                          ⎥
# ⎢                                                                   ⎥
# ⎢                                 2                                 ⎥
# ⎢                                ρ               2                  ⎥
# ⎢f(ρ, z)⋅ω(ρ, z)      0       ─────── - f(ρ, z)⋅ω (ρ, z)      0     ⎥
# ⎢                             f(ρ, z)                               ⎥
# ⎢                                                                   ⎥
# ⎢                                                          2⋅γ(ρ, z)⎥
# ...

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡   -f(ρ, z)          0            f(ρ, z)⋅ω(ρ, z)            0     ⎤
# ⎢                                                                   ⎥
# ⎢                  2⋅γ(ρ, z)                                        ⎥
# ⎢                 ℯ                                                 ⎥
# ⎢       0         ──────────              0                   0     ⎥
# ⎢                  f(ρ, z)                                          ⎥
# ⎢                                                                   ⎥
# ⎢                                 2                                 ⎥
# ⎢                                ρ               2                  ⎥
# ⎢f(ρ, z)⋅ω(ρ, z)      0       ─────── - f(ρ, z)⋅ω (ρ, z)      0     ⎥
# ⎢                             f(ρ, z)                               ⎥
# ⎢                                                                   ⎥
# ⎢                                                          2⋅γ(ρ, z)⎥
# ...

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("t rho phi z")
t,rho,phi,z = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
simplify(ch.tensor())
# Out:
# ⎡⎡                                                             ∂              2
# ⎢⎢                                                             ──(f(ρ, z))   f (ρ, z)⋅ω(ρ, z
# ⎢⎢                                                             ∂ρ
# ⎢⎢                    0                                        ─────────── + ───────────────
# ⎢⎢                                                              2⋅f(ρ, z)
# ⎢⎢                                                                                       2⋅ρ
# ⎢⎢
# ⎢⎢∂              2               ∂
# ⎢⎢──(f(ρ, z))   f (ρ, z)⋅ω(ρ, z)⋅──(ω(ρ, z))
# ⎢⎢∂ρ                             ∂ρ
# ⎢⎢─────────── + ────────────────────────────                                        0
# ⎢⎢ 2⋅f(ρ, z)                   2
# ⎢⎢                          2⋅ρ
# ⎢⎢
# ⎢⎢                                              ∂                     ∂
# ⎢⎢                                              ──(ω(ρ, z))   ω(ρ, z)⋅──(f(ρ, z))
# ...

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢⎛                2                          2                                 2
# ⎢⎜   2  2        ∂              2  2        ∂              2                  ∂
# ⎢⎜- ρ ⋅f (ρ, z)⋅───(ω(ρ, z)) - ρ ⋅f (ρ, z)⋅───(ω(ρ, z)) - ρ ⋅f(ρ, z)⋅ω(ρ, z)⋅───(f(ρ, z)) -
# ⎢⎜                2                          2                                 2
# ⎢⎝              ∂ρ                         ∂z                                ∂ρ
# ⎢───────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                 ⎛             2                         2                            2
#                 ⎜ 2          ∂              2          ∂              2 ⎛∂          ⎞     2
#                 ⎜ρ ⋅f(ρ, z)⋅───(f(ρ, z)) + ρ ⋅f(ρ, z)⋅───(f(ρ, z)) - ρ ⋅⎜──(f(ρ, z))⎟  - ρ ⋅
# ...

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr
# Out:
# ⎛     ⎛             2                  2⎞      ⎛               2                2⎞        ⎛
# ⎜   2 ⎜⎛∂          ⎞      ⎛∂          ⎞ ⎟    2 ⎜  ⎛∂          ⎞    ⎛∂          ⎞ ⎟      2 ⎜
# ⎜- ρ ⋅⎜⎜──(f(ρ, z))⎟  + 2⋅⎜──(f(ρ, z))⎟ ⎟ - ρ ⋅⎜2⋅⎜──(f(ρ, z))⎟  + ⎜──(f(ρ, z))⎟ ⎟ + 2⋅ρ ⋅⎜─
# ⎜     ⎝⎝∂ρ         ⎠      ⎝∂z         ⎠ ⎠      ⎝  ⎝∂ρ         ⎠    ⎝∂z         ⎠ ⎠        ⎜
# ⎝                                                                                         ⎝∂
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#  2              2         ⎞                ⎛  2              2         ⎞
# ∂              ∂          ⎟              2 ⎜ ∂              ∂          ⎟  2
# ──(f(ρ, z)) + ───(f(ρ, z))⎟⋅f(ρ, z) - 4⋅ρ ⋅⎜───(γ(ρ, z)) + ───(γ(ρ, z))⎟⋅f (ρ, z) + 2⋅ρ⋅f(ρ,
#  2              2         ⎟                ⎜  2              2         ⎟
# ρ             ∂z          ⎠                ⎝∂ρ             ∂z          ⎠
# ...

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢       ⎛     ⎛             2                  2⎞      ⎛               2                2⎞
# ⎢       ⎜   2 ⎜⎛∂          ⎞      ⎛∂          ⎞ ⎟    2 ⎜  ⎛∂          ⎞    ⎛∂          ⎞ ⎟
# ⎢  0.25⋅⎜- ρ ⋅⎜⎜──(f(ρ, z))⎟  + 2⋅⎜──(f(ρ, z))⎟ ⎟ - ρ ⋅⎜2⋅⎜──(f(ρ, z))⎟  + ⎜──(f(ρ, z))⎟ ⎟ +
# ⎢       ⎜     ⎝⎝∂ρ         ⎠      ⎝∂z         ⎠ ⎠      ⎝  ⎝∂ρ         ⎠    ⎝∂z         ⎠ ⎠
# ⎢       ⎝
# ⎢- ─────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                           ⎛     ⎛             2                  2⎞      ⎛               2
#                           ⎜   2 ⎜⎛∂          ⎞      ⎛∂          ⎞ ⎟    2 ⎜  ⎛∂          ⎞
#                      0.25⋅⎜- ρ ⋅⎜⎜──(f(ρ, z))⎟  + 2⋅⎜──(f(ρ, z))⎟ ⎟ - ρ ⋅⎜2⋅⎜──(f(ρ, z))⎟  +
#                           ⎜     ⎝⎝∂ρ         ⎠      ⎝∂z         ⎠ ⎠      ⎝  ⎝∂ρ         ⎠
# ...

# %%
#  rm1 = RiemannCurvatureTensor.from_christoffels(ch)
#  rm1.tensor()

# %%
#  weyl = WeylTensor.from_metric(metric)
#  weyl.tensor()

# %%
ricciSimplified = simplify(Ric.tensor())
ricciSimplified
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢⎛                2                          2                                 2
# ⎢⎜   2  2        ∂              2  2        ∂              2                  ∂
# ⎢⎜- ρ ⋅f (ρ, z)⋅───(ω(ρ, z)) - ρ ⋅f (ρ, z)⋅───(ω(ρ, z)) - ρ ⋅f(ρ, z)⋅ω(ρ, z)⋅───(f(ρ, z)) -
# ⎢⎜                2                          2                                 2
# ⎢⎝              ∂ρ                         ∂z                                ∂ρ
# ⎢───────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                 ⎛             2                         2                            2
#                 ⎜ 2          ∂              2          ∂              2 ⎛∂          ⎞     2
#                 ⎜ρ ⋅f(ρ, z)⋅───(f(ρ, z)) + ρ ⋅f(ρ, z)⋅───(f(ρ, z)) - ρ ⋅⎜──(f(ρ, z))⎟  - ρ ⋅
# ...

# %%
einsteinSimplified = simplify(einst.tensor())
einsteinSimplified
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢    ⎛                          2                                      2
# ⎢    ⎜     2  2                ∂                  2  2                ∂              2  2
# ⎢0.5⋅⎜2.0⋅ρ ⋅f (ρ, z)⋅ω(ρ, z)⋅───(γ(ρ, z)) + 2.0⋅ρ ⋅f (ρ, z)⋅ω(ρ, z)⋅───(γ(ρ, z)) - ρ ⋅f (ρ,
# ⎢    ⎜                          2                                      2
# ⎢    ⎝                        ∂ρ                                     ∂z
# ⎢───────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                               ⎛                    2                              2
#                               ⎜       2  2        ∂                  2  2        ∂
#                           0.5⋅⎜- 2.0⋅ρ ⋅f (ρ, z)⋅───(γ(ρ, z)) - 2.0⋅ρ ⋅f (ρ, z)⋅───(γ(ρ, z))
#                               ⎜                    2                              2
# ...

# %%
d2fdz2 = Eq( diff(f,z,z) , solve( ricciSimplified[0,2].args[2] , diff(f,z,z) )[0] ) 
d2fdz2
# Out:
#                            2                      2
#                           ∂                      ∂
#                  f(ρ, z)⋅───(ω(ρ, z))   f(ρ, z)⋅───(ω(ρ, z))                    ∂
#   2                        2                      2              2            2⋅──(f(ρ, z))⋅
#  ∂                       ∂ρ                     ∂z              ∂               ∂ρ
# ───(f(ρ, z)) = - ──────────────────── - ──────────────────── - ───(f(ρ, z)) - ──────────────
#   2                    ω(ρ, z)                ω(ρ, z)            2                     ω(ρ,
# ∂z                                                             ∂ρ
#
#
#                                                        2                2
# ∂               ∂           ∂             ⎛∂          ⎞    ⎛∂          ⎞            ∂
# ──(ω(ρ, z))   2⋅──(f(ρ, z))⋅──(ω(ρ, z))   ⎜──(f(ρ, z))⎟    ⎜──(f(ρ, z))⎟    f(ρ, z)⋅──(ω(ρ,
# ∂ρ              ∂z          ∂z            ⎝∂ρ         ⎠    ⎝∂z         ⎠            ∂ρ
# ...

# %%
omegaWave = Eq(diff(omega,rho,rho),solve( simplify(ricciSimplified[2,2].args[3].subs(d2fdz2.args[0],d2fdz2.args[1])) , diff(omega,rho,rho) )[0])
omegaWave
# Out:
#                                   ∂           ∂               ∂           ∂             ∂
#   2                2            2⋅──(f(ρ, z))⋅──(ω(ρ, z))   2⋅──(f(ρ, z))⋅──(ω(ρ, z))   ──(ω
#  ∂                ∂               ∂ρ          ∂ρ              ∂z          ∂z            ∂ρ
# ───(ω(ρ, z)) = - ───(ω(ρ, z)) - ───────────────────────── - ───────────────────────── + ────
#   2                2                     f(ρ, z)                     f(ρ, z)
# ∂ρ               ∂z
#
#
# (ρ, z))
#
# ───────
#  ρ

# %%
dGammadZ = Eq(diff(gamma,z) ,expand( solve( ricciSimplified[1,3] , diff(gamma,z) )[0] ) )
dGammadZ
# Out:
#                 ∂           ∂              2       ∂           ∂
#               ρ⋅──(f(ρ, z))⋅──(f(ρ, z))   f (ρ, z)⋅──(ω(ρ, z))⋅──(ω(ρ, z))
# ∂               ∂ρ          ∂z                     ∂ρ          ∂z
# ──(γ(ρ, z)) = ───────────────────────── - ────────────────────────────────
# ∂z                       2                              2⋅ρ
#                       2⋅f (ρ, z)

# %%
dGammadRho = Eq(diff(gamma,rho),expand( solve( einsteinSimplified[1,1] , diff(gamma,rho) )[0] ) )
dGammadRho
# Out:
#                                   2                       2                              2
#                      ⎛∂          ⎞           ⎛∂          ⎞          2       ⎛∂          ⎞
#               0.25⋅ρ⋅⎜──(f(ρ, z))⎟    0.25⋅ρ⋅⎜──(f(ρ, z))⎟    0.25⋅f (ρ, z)⋅⎜──(ω(ρ, z))⎟
# ∂                    ⎝∂ρ         ⎠           ⎝∂z         ⎠                  ⎝∂ρ         ⎠
# ──(γ(ρ, z)) = ───────────────────── - ───────────────────── - ──────────────────────────── +
# ∂ρ                    2                       2                            ρ
#                      f (ρ, z)                f (ρ, z)
#
#                             2
#        2       ⎛∂          ⎞
#  0.25⋅f (ρ, z)⋅⎜──(ω(ρ, z))⎟
#                ⎝∂z         ⎠
#  ────────────────────────────
#               ρ

# %%
fWave = Eq( diff(f,rho,rho) , solve( ricciSimplified[0,0].args[2] , diff(f,rho,rho) )[0] ).subs(dGammadRho.args[0],dGammadRho.args[1])
fWave
# Out:
#                                              2                2
#                                 ⎛∂          ⎞    ⎛∂          ⎞    ∂              3       ⎛∂
#   2                2            ⎜──(f(ρ, z))⎟    ⎜──(f(ρ, z))⎟    ──(f(ρ, z))   f (ρ, z)⋅⎜──
#  ∂                ∂             ⎝∂ρ         ⎠    ⎝∂z         ⎠    ∂ρ                     ⎝∂ρ
# ───(f(ρ, z)) = - ───(f(ρ, z)) + ────────────── + ────────────── - ─────────── - ────────────
#   2                2               f(ρ, z)          f(ρ, z)            ρ
# ∂ρ               ∂z                                                                        ρ
#
#           2                         2
#          ⎞     3       ⎛∂          ⎞
# (ω(ρ, z))⎟    f (ρ, z)⋅⎜──(ω(ρ, z))⎟
#          ⎠             ⎝∂z         ⎠
# ─────────── - ───────────────────────
# 2                         2
#                          ρ

# %%
vacuumFieldEquations = Matrix([fWave,omegaWave ,dGammadRho ,dGammadZ ])
vacuumFieldEquations
# Out:
# ⎡                                             2                2
# ⎢                                ⎛∂          ⎞    ⎛∂          ⎞    ∂              3       ⎛∂
# ⎢  2                2            ⎜──(f(ρ, z))⎟    ⎜──(f(ρ, z))⎟    ──(f(ρ, z))   f (ρ, z)⋅⎜─
# ⎢ ∂                ∂             ⎝∂ρ         ⎠    ⎝∂z         ⎠    ∂ρ                     ⎝∂
# ⎢───(f(ρ, z)) = - ───(f(ρ, z)) + ────────────── + ────────────── - ─────────── - ───────────
# ⎢  2                2               f(ρ, z)          f(ρ, z)            ρ
# ⎢∂ρ               ∂z
# ⎢
# ⎢                                                 ∂           ∂               ∂           ∂
# ⎢                 2                2            2⋅──(f(ρ, z))⋅──(ω(ρ, z))   2⋅──(f(ρ, z))⋅──
# ⎢                ∂                ∂               ∂ρ          ∂ρ              ∂z          ∂z
# ⎢               ───(ω(ρ, z)) = - ───(ω(ρ, z)) - ───────────────────────── - ────────────────
# ...

# %% [markdown]
# It is instructive to compare these equations with those numbered 12-15 in "Big Bang in T3 Gowdy Cosmological Models" by Quevedo.  With the appropriate identification between f and psi ( see metrics ) these should be equivalent
