# %% [markdown]
# # Gravitational Waves in General Relativity V An Exact Spherical Wave by Marder
# ##  Geoff Cope
# ##  Univeristy of Utah
# ##  December 22, 2021

# %% [markdown]
# Metric Taken From Gravitational Waves in General Relativity V. An Exact Spherical Wave.  The paper starts with metric 1, does a series of transformations and winds up with metric 4 which we use here.

# %% [markdown]
# https://www.jstor.org/stable/2413901

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
T,R,phi,zeta,dT,dR,dphi,dzeta = symbols( 'T R phi zeta dT dR dphi dzeta' )

# %%
variables = Matrix( [T,R,phi,zeta] )
variables
# Out:
# ⎡T⎤
# ⎢ ⎥
# ⎢R⎥
# ⎢ ⎥
# ⎢φ⎥
# ⎢ ⎥
# ⎣ζ⎦

# %%
differentials = Matrix( [dT,dR,dphi,dzeta])
differentials
# Out:
# ⎡ dT  ⎤
# ⎢     ⎥
# ⎢ dR  ⎥
# ⎢     ⎥
# ⎢dphi ⎥
# ⎢     ⎥
# ⎣dzeta⎦

# %%
psi = Function('psi')(R,T)
psi
# Out:
# ψ(R, T)

# %%
gamma = Function('gamma')(R,T)
gamma
# Out:
# γ(R, T)

# %%
lineElement = expand(( - dR**2 + dT**2 ) * exp(2*(gamma-psi)) - dzeta**2 * exp(2*psi) - dphi**2 * exp(-2*psi) * R**2 )
lineElement
# Out:
#    2     2  -2⋅ψ(R, T)     2  2⋅γ(R, T)  -2⋅ψ(R, T)     2  2⋅γ(R, T)  -2⋅ψ(R, T)        2  2
# - R ⋅dphi ⋅ℯ           - dR ⋅ℯ         ⋅ℯ           + dT ⋅ℯ         ⋅ℯ           - dzeta ⋅ℯ
#
# ⋅ψ(R, T)

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡ 2⋅γ(R, T)  -2⋅ψ(R, T)                                                       ⎤
# ⎢ℯ         ⋅ℯ                       0                    0              0     ⎥
# ⎢                                                                             ⎥
# ⎢                          2⋅γ(R, T)  -2⋅ψ(R, T)                              ⎥
# ⎢          0             -ℯ         ⋅ℯ                   0              0     ⎥
# ⎢                                                                             ⎥
# ⎢                                                   2  -2⋅ψ(R, T)             ⎥
# ⎢          0                        0             -R ⋅ℯ                 0     ⎥
# ⎢                                                                             ⎥
# ⎢                                                                    2⋅ψ(R, T)⎥
# ⎣          0                        0                    0         -ℯ         ⎦

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡ 2⋅γ(R, T)  -2⋅ψ(R, T)                                                       ⎤
# ⎢ℯ         ⋅ℯ                       0                    0              0     ⎥
# ⎢                                                                             ⎥
# ⎢                          2⋅γ(R, T)  -2⋅ψ(R, T)                              ⎥
# ⎢          0             -ℯ         ⋅ℯ                   0              0     ⎥
# ⎢                                                                             ⎥
# ⎢                                                   2  -2⋅ψ(R, T)             ⎥
# ⎢          0                        0             -R ⋅ℯ                 0     ⎥
# ⎢                                                                             ⎥
# ⎢                                                                    2⋅ψ(R, T)⎥
# ⎣          0                        0                    0         -ℯ         ⎦

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("T R phi zeta")
t,r,phi,zeta = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
simplify(ch.tensor())
# Out:
# ⎡⎡∂             ∂            ∂             ∂
# ⎢⎢──(γ(R, T)) - ──(ψ(R, T))  ──(γ(R, T)) - ──(ψ(R, T))               0
# ⎢⎢∂T            ∂T           ∂R            ∂R
# ⎢⎢
# ⎢⎢∂             ∂            ∂             ∂
# ⎢⎢──(γ(R, T)) - ──(ψ(R, T))  ──(γ(R, T)) - ──(ψ(R, T))               0
# ⎢⎢∂R            ∂R           ∂T            ∂T
# ⎢⎢
# ⎢⎢                                                        2  -2⋅γ(R, T) ∂
# ⎢⎢            0                          0              -R ⋅ℯ          ⋅──(ψ(R, T))
# ⎢⎢                                                                      ∂T
# ⎢⎢
# ⎢⎢                                                                                    -2⋅γ(R
# ⎢⎢            0                          0                           0               ℯ
# ⎣⎣
#
#                             ⎤  ⎡∂             ∂            ∂             ∂
#           0                 ⎥  ⎢──(γ(R, T)) - ──(ψ(R, T))  ──(γ(R, T)) - ──(ψ(R, T))
# ...

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()
# Out:
# ⎡  ⎛  2              2              2                           2     2         ⎞
# ⎢  ⎜ ∂              ∂              ∂               ⎛∂          ⎞     ∂          ⎟   ∂
# ⎢R⋅⎜───(γ(R, T)) - ───(γ(R, T)) - ───(ψ(R, T)) - 2⋅⎜──(ψ(R, T))⎟  + ───(ψ(R, T))⎟ + ──(γ(R,
# ⎢  ⎜  2              2              2              ⎝∂T         ⎠      2         ⎟   ∂R
# ⎢  ⎝∂R             ∂T             ∂R                                ∂T          ⎠
# ⎢───────────────────────────────────────────────────────────────────────────────────────────
# ⎢                                                     R
# ⎢
# ⎢
# ⎢
# ⎢                                                               ∂
# ⎢                                                               ──(γ(R, T))
# ⎢                                     ∂           ∂             ∂T
# ⎢                                 - 2⋅──(ψ(R, T))⋅──(ψ(R, T)) + ───────────
# ⎢                                     ∂R          ∂T                 R
# ⎢
# ⎢
# ⎢
# ...

# %%
einst = EinsteinTensor.from_metric(metric)
simplify(einst.tensor())
# Out:
# ⎡                                        ∂                                               ∂
# ⎢               2                2   1.0⋅──(γ(R, T))                                     ──(
# ⎢  ⎛∂          ⎞    ⎛∂          ⎞        ∂R                    ∂           ∂             ∂T
# ⎢- ⎜──(ψ(R, T))⎟  - ⎜──(ψ(R, T))⎟  + ───────────────       - 2⋅──(ψ(R, T))⋅──(ψ(R, T)) + ───
# ⎢  ⎝∂R         ⎠    ⎝∂T         ⎠           R                  ∂R          ∂T
# ⎢
# ⎢                                   ∂
# ⎢                                   ──(γ(R, T))                      2                2   1.
# ⎢         ∂           ∂             ∂T                  ⎛∂          ⎞    ⎛∂          ⎞
# ⎢     - 2⋅──(ψ(R, T))⋅──(ψ(R, T)) + ───────────       - ⎜──(ψ(R, T))⎟  - ⎜──(ψ(R, T))⎟  + ──
# ⎢         ∂R          ∂T                 R              ⎝∂R         ⎠    ⎝∂T         ⎠
# ⎢
# ⎢
# ⎢
# ⎢                         0                                                    0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ...

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr
# Out:
#   ⎛    2                2                           2       2                           2
#   ⎜   ∂                ∂               ⎛∂          ⎞       ∂               ⎛∂          ⎞
# 2⋅⎜R⋅───(γ(R, T)) - R⋅───(γ(R, T)) + R⋅⎜──(ψ(R, T))⎟  - R⋅───(ψ(R, T)) - R⋅⎜──(ψ(R, T))⎟  +
#   ⎜    2                2              ⎝∂R         ⎠        2              ⎝∂T         ⎠
#   ⎝  ∂R               ∂T                                  ∂R
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                         R
#
#     2                       ⎞
#    ∂             ∂          ⎟  -2⋅γ(R, T) + 2⋅ψ(R, T)
# R⋅───(ψ(R, T)) - ──(ψ(R, T))⎟⋅ℯ
#     2            ∂R         ⎟
#   ∂T                        ⎠
# ─────────────────────────────────────────────────────

# %%
rm1 = RiemannCurvatureTensor.from_christoffels(ch)
simplify(rm1.tensor())
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢⎡
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                         0
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                         0
# ⎢⎢
# ⎢⎢
# ⎢⎢  ⎛                                                                   2     2         ⎞
# ⎢⎢  ⎜  ∂           ∂             ∂           ∂             ⎛∂          ⎞     ∂          ⎟
# ⎢⎢R⋅⎜- ──(γ(R, T))⋅──(ψ(R, T)) - ──(γ(R, T))⋅──(ψ(R, T)) + ⎜──(ψ(R, T))⎟  + ───(ψ(R, T))⎟ +
# ⎢⎢  ⎜  ∂R          ∂R            ∂T          ∂T            ⎝∂R         ⎠      2         ⎟
# ⎢⎢  ⎝                                                                       ∂T          ⎠
# ⎢⎢──────────────────────────────────────────────────────────────────────────────────────────
# ⎢⎢                                                         R
# ⎢⎢
# ...

# %%
weyl = WeylTensor.from_metric(metric)
simplify(weyl.tensor())
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢⎡
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢  ⎛                                  2                                              2
# ⎢⎢  ⎜    ∂           ∂                ∂                 ∂           ∂                ∂
# ⎢⎢R⋅⎜6⋅R⋅──(γ(R, T))⋅──(ψ(R, T)) + R⋅───(γ(R, T)) + 6⋅R⋅──(γ(R, T))⋅──(ψ(R, T)) - R⋅───(γ(R,
# ⎢⎢  ⎜    ∂R          ∂R                2                ∂T          ∂T                2
# ⎢⎢  ⎝                                ∂R                                             ∂T
# ⎢⎢──────────────────────────────────────────────────────────────────────────────────────────
# ⎢⎢
# ⎢⎢
# ⎢⎣
# ⎢
# ⎢      ⎡
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ⎢      ⎢
# ...
