# %% [markdown]
# # Polarized Gowdy Spacetime
# ##  Geoff Cope
# ##  University of Utah
# ##  December 22, 2021

# %% [markdown]
# The Polarized Gowdy Spacetime Metric is taken from the paper "SHOCK WAVES AND GRAVITATIONAL WAVES
# IN MATTER SPACETIMES WITH GOWDY SYMMETRY" by LeFloch and Stewart.  See Equation 2.1

# %% [markdown]
# http://emis.maths.adelaide.edu.au/journals/PM/62f3/pm62f308.pdf

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
a,b,c,t,x,y,z,dt,dx,dy,dz = symbols( 'a b c t x y z dt dx dy dz' )

# %%
variables = Matrix( [t,x,y,z])
variables
# Out:
# ⎡t⎤
# ⎢ ⎥
# ⎢x⎥
# ⎢ ⎥
# ⎢y⎥
# ⎢ ⎥
# ⎣z⎦

# %%
differentials = Matrix( [dt,dx,dy,dz])
differentials
# Out:
# ⎡dt⎤
# ⎢  ⎥
# ⎢dx⎥
# ⎢  ⎥
# ⎢dy⎥
# ⎢  ⎥
# ⎣dz⎦

# %%
a = Function('a')(t,x)
a
# Out:
# a(t, x)

# %%
b = Function('b')(t,x)
b
# Out:
# b(t, x)

# %%
c = Function('c')(t,x)
c
# Out:
# c(t, x)

# %%
lineElement = expand(exp(2*a)*( (-1)*dt**2 + dx**2 ) - exp(2*b) * ( exp(2*c) * dy**2 + exp(-2*c) * dz**2 ))
lineElement
# Out:
#     2  2⋅a(t, x)     2  2⋅a(t, x)     2  2⋅b(t, x)  2⋅c(t, x)     2  2⋅b(t, x)  -2⋅c(t, x)
# - dt ⋅ℯ          + dx ⋅ℯ          - dy ⋅ℯ         ⋅ℯ          - dz ⋅ℯ         ⋅ℯ

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡  2⋅a(t, x)                                                             ⎤
# ⎢-ℯ               0                 0                        0           ⎥
# ⎢                                                                        ⎥
# ⎢              2⋅a(t, x)                                                 ⎥
# ⎢     0       ℯ                     0                        0           ⎥
# ⎢                                                                        ⎥
# ⎢                           2⋅b(t, x)  2⋅c(t, x)                         ⎥
# ⎢     0           0       -ℯ         ⋅ℯ                      0           ⎥
# ⎢                                                                        ⎥
# ⎢                                                   2⋅b(t, x)  -2⋅c(t, x)⎥
# ⎣     0           0                 0             -ℯ         ⋅ℯ          ⎦

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡  2⋅a(t, x)                                                             ⎤
# ⎢-ℯ               0                 0                        0           ⎥
# ⎢                                                                        ⎥
# ⎢              2⋅a(t, x)                                                 ⎥
# ⎢     0       ℯ                     0                        0           ⎥
# ⎢                                                                        ⎥
# ⎢                           2⋅b(t, x)  2⋅c(t, x)                         ⎥
# ⎢     0           0       -ℯ         ⋅ℯ                      0           ⎥
# ⎢                                                                        ⎥
# ⎢                                                   2⋅b(t, x)  -2⋅c(t, x)⎥
# ⎣     0           0                 0             -ℯ         ⋅ℯ          ⎦

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("t x y z")
t,x,y,z = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
simplify(ch.tensor())
# Out:
# ⎡⎡∂            ∂
# ⎢⎢──(a(t, x))  ──(a(t, x))                                 0
# ⎢⎢∂t           ∂x
# ⎢⎢
# ⎢⎢∂            ∂
# ⎢⎢──(a(t, x))  ──(a(t, x))                                 0
# ⎢⎢∂x           ∂t
# ⎢⎢
# ⎢⎢                           ⎛∂             ∂          ⎞  -2⋅a(t, x) + 2⋅b(t, x) + 2⋅c(t, x)
# ⎢⎢     0            0       -⎜──(b(t, x)) + ──(c(t, x))⎟⋅ℯ
# ⎢⎢                           ⎝∂t            ∂t         ⎠
# ⎢⎢
# ⎢⎢
# ⎢⎢     0            0                                      0
# ⎣⎣
#
#                                                                    ⎤  ⎡∂            ∂
#                                   0                                ⎥  ⎢──(a(t, x))  ──(a(t,
#                                                                    ⎥  ⎢∂x           ∂t
#                                                                    ⎥  ⎢
#                                                                    ⎥  ⎢∂            ∂
# ...

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()
# Out:
# ⎡                              2                                          2
# ⎢  ∂           ∂              ∂               ∂           ∂              ∂               ⎛∂
# ⎢2⋅──(a(t, x))⋅──(b(t, x)) - ───(a(t, x)) + 2⋅──(a(t, x))⋅──(b(t, x)) + ───(a(t, x)) - 2⋅⎜──
# ⎢  ∂t          ∂t              2              ∂x          ∂x              2              ⎝∂t
# ⎢                            ∂t                                         ∂x
# ⎢
# ⎢
# ⎢       ∂           ∂               ∂           ∂               ∂           ∂
# ⎢     2⋅──(a(t, x))⋅──(b(t, x)) + 2⋅──(a(t, x))⋅──(b(t, x)) - 2⋅──(b(t, x))⋅──(b(t, x)) - 2⋅
# ⎢       ∂t          ∂x              ∂x          ∂t              ∂t          ∂x
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                    0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                    0
# ⎢
# ⎣
#
#           2       2                           2
# ...

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()
# Out:
# ⎡                                                                         2
# ⎢  ∂           ∂               ∂           ∂                 ⎛∂          ⎞        ⎛∂
# ⎢2⋅──(a(t, x))⋅──(b(t, x)) + 2⋅──(a(t, x))⋅──(b(t, x)) + 1.0⋅⎜──(b(t, x))⎟  - 3.0⋅⎜──(b(t, x
# ⎢  ∂t          ∂t              ∂x          ∂x                ⎝∂t         ⎠        ⎝∂x
# ⎢
# ⎢
# ⎢
# ⎢            ∂           ∂               ∂           ∂               ∂           ∂
# ⎢          2⋅──(a(t, x))⋅──(b(t, x)) + 2⋅──(a(t, x))⋅──(b(t, x)) - 2⋅──(b(t, x))⋅──(b(t, x))
# ⎢            ∂t          ∂x              ∂x          ∂t              ∂t          ∂x
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                         0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                         0
# ⎢
# ⎣
#
#    2         2                         2                2
#   ⎞         ∂             ⎛∂          ⎞    ⎛∂          ⎞               ∂           ∂
# ...

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr
# Out:
#   ⎛  2              2                           2       2                           2
#   ⎜ ∂              ∂               ⎛∂          ⎞       ∂               ⎛∂          ⎞       ∂
# 2⋅⎜───(a(t, x)) - ───(a(t, x)) + 3⋅⎜──(b(t, x))⎟  + 2⋅───(b(t, x)) - 3⋅⎜──(b(t, x))⎟  - 2⋅──
#   ⎜  2              2              ⎝∂t         ⎠        2              ⎝∂x         ⎠
#   ⎝∂t             ∂x                                  ∂t                                  ∂x
#
# 2                         2                2⎞
#              ⎛∂          ⎞    ⎛∂          ⎞ ⎟  -2⋅a(t, x)
# ─(b(t, x)) + ⎜──(c(t, x))⎟  - ⎜──(c(t, x))⎟ ⎟⋅ℯ
# 2            ⎝∂t         ⎠    ⎝∂x         ⎠ ⎟
#                                             ⎠

# %%
rm1 = RiemannCurvatureTensor.from_christoffels(ch)
rm1.tensor()
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢⎡
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢∂           ∂             ∂           ∂             ∂           ∂             ∂
# ⎢⎢──(a(t, x))⋅──(b(t, x)) + ──(a(t, x))⋅──(c(t, x)) + ──(a(t, x))⋅──(b(t, x)) + ──(a(t, x))⋅
# ⎢⎢∂t          ∂t            ∂t          ∂t            ∂x          ∂x            ∂x
# ⎢⎢
# ⎢⎢
# ⎢⎣
# ⎢
# ⎢⎡
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢∂           ∂             ∂           ∂             ∂           ∂             ∂
# ⎢⎢──(a(t, x))⋅──(b(t, x)) - ──(a(t, x))⋅──(c(t, x)) + ──(a(t, x))⋅──(b(t, x)) - ──(a(t, x))⋅
# ⎢⎢∂t          ∂t            ∂t          ∂t            ∂x          ∂x            ∂x
# ⎣⎣
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       0
#
#
#
#
#
#       0
#
#
# ...

# %%
weyl = WeylTensor.from_metric(metric)
weyl.tensor()
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢⎡
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢⎛                              2                                        2
# ⎢⎢⎜                             ∂                                        ∂
# ⎢⎢⎜                            ───(a(t, x))                             ───(a(t, x))
# ⎢⎢⎜                              2                                        2
# ⎢⎢⎜  ∂           ∂             ∂t             ∂           ∂             ∂x             ∂
# ⎢⎢⎜- ──(a(t, x))⋅──(c(t, x)) - ──────────── - ──(a(t, x))⋅──(c(t, x)) + ──────────── + ──(b(
# ⎢⎢⎝  ∂t          ∂t                 6         ∂x          ∂x                 6         ∂t
# ⎢⎢
# ⎢⎣
# ⎢
# ⎢ ⎡
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ⎢ ⎢
# ...
