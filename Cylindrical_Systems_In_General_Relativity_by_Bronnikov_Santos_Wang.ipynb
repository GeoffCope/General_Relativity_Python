# %% [markdown]
# # Cylindrical Systems In General Relativity by Bronnikov  Santos and Wang
# ##  Geoff Cope
# ##  Univeristy of Utah
# ##  December 22, 2021

# %% [markdown]
# This is a very long paper with quite a few metrics, here we concentrate on metric 9.2  This metric also appears in the paper "Gravitational Analaogue of Farady Rotation by Piran and Safier" linked to down below.  We'll finish the other metrics at a later date.

# %% [markdown]
# https://arxiv.org/abs/1901.06561

# %% [markdown]
# https://www.nature.com/articles/318271a0

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
t,r,phi,z,dt,dr,dphi,dz = symbols( 't r phi z dt dr dphi dz' )

# %%
psi, omega, gamma = symbols( 'psi omega gamma')

# %%
psi = Function('psi')(r,t)
psi
# Out:
# ψ(r, t)

# %%
omega = Function('omega')(r,t)
omega
# Out:
# ω(r, t)

# %%
gamma = Function('gamma')(r,t)
gamma
# Out:
# γ(r, t)

# %%
variables = Matrix( [t,r,phi,z] )
variables
# Out:
# ⎡t⎤
# ⎢ ⎥
# ⎢r⎥
# ⎢ ⎥
# ⎢φ⎥
# ⎢ ⎥
# ⎣z⎦

# %%
differentials = Matrix( [dt,dr,dphi,dz] ) 
differentials
# Out:
# ⎡ dt ⎤
# ⎢    ⎥
# ⎢ dr ⎥
# ⎢    ⎥
# ⎢dphi⎥
# ⎢    ⎥
# ⎣ dz ⎦

# %%
lineElement = expand(exp(2*(gamma-psi)) * (dt**2 - dr**2) - exp(2*psi) * (dz + omega * dphi)**2 - r**2*exp(-2*psi)*dphi**2)
lineElement
# Out:
#       2  2  -2⋅ψ(r, t)       2  2        2⋅ψ(r, t)                      2⋅ψ(r, t)     2  2⋅γ
# - dphi ⋅r ⋅ℯ           - dphi ⋅ω (r, t)⋅ℯ          - 2⋅dphi⋅dz⋅ω(r, t)⋅ℯ          - dr ⋅ℯ
#
# (r, t)  -2⋅ψ(r, t)     2  2⋅γ(r, t)  -2⋅ψ(r, t)     2  2⋅ψ(r, t)
#       ⋅ℯ           + dt ⋅ℯ         ⋅ℯ           - dz ⋅ℯ

# %%
g = zeros(4)

for i in range(4):
    for j in range(4):
        if i == j:
            g[i,j] = lineElement.coeff( differentials[i],2 ) 
        else:
            g[i,j] = Rational(1,2)*lineElement.coeff( differentials[i]*differentials[j],1 )
            
g
# Out:
# ⎡ 2⋅γ(r, t)  -2⋅ψ(r, t)
# ⎢ℯ         ⋅ℯ                       0                               0
# ⎢
# ⎢                          2⋅γ(r, t)  -2⋅ψ(r, t)
# ⎢          0             -ℯ         ⋅ℯ                              0
# ⎢
# ⎢                                                    2  -2⋅ψ(r, t)    2        2⋅ψ(r, t)
# ⎢          0                        0             - r ⋅ℯ           - ω (r, t)⋅ℯ           -ω
# ⎢
# ⎢                                                                    2⋅ψ(r, t)
# ⎣          0                        0                      -ω(r, t)⋅ℯ
#
#                  ⎤
#        0         ⎥
#                  ⎥
#                  ⎥
#        0         ⎥
#                  ⎥
#         2⋅ψ(r, t)⎥
# (r, t)⋅ℯ         ⎥
#                  ⎥
#     2⋅ψ(r, t)    ⎥
#   -ℯ             ⎦

# %%
import sympy

# %%
m = sympy.Array(g)
m
# Out:
# ⎡ 2⋅γ(r, t)  -2⋅ψ(r, t)
# ⎢ℯ         ⋅ℯ                       0                               0
# ⎢
# ⎢                          2⋅γ(r, t)  -2⋅ψ(r, t)
# ⎢          0             -ℯ         ⋅ℯ                              0
# ⎢
# ⎢                                                    2  -2⋅ψ(r, t)    2        2⋅ψ(r, t)
# ⎢          0                        0             - r ⋅ℯ           - ω (r, t)⋅ℯ           -ω
# ⎢
# ⎢                                                                    2⋅ψ(r, t)
# ⎣          0                        0                      -ω(r, t)⋅ℯ
#
#                  ⎤
#        0         ⎥
#                  ⎥
#                  ⎥
#        0         ⎥
#                  ⎥
#         2⋅ψ(r, t)⎥
# (r, t)⋅ℯ         ⎥
#                  ⎥
#     2⋅ψ(r, t)    ⎥
#   -ℯ             ⎦

# %%
from einsteinpy.symbolic import *

# %%
syms = sympy.symbols("t r phi z")
t,r,phi,z = syms

# %%
metric = MetricTensor(m,syms)

# %%
ch = ChristoffelSymbols.from_metric(metric)
simplify(ch.tensor())
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢⎡∂             ∂            ∂             ∂
# ⎢⎢──(γ(r, t)) - ──(ψ(r, t))  ──(γ(r, t)) - ──(ψ(r, t))
# ⎢⎢∂t            ∂t           ∂r            ∂r
# ⎢⎢
# ⎢⎢∂             ∂            ∂             ∂
# ⎢⎢──(γ(r, t)) - ──(ψ(r, t))  ──(γ(r, t)) - ──(ψ(r, t))
# ⎢⎢∂r            ∂r           ∂t            ∂t
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                      ⎛   2 ∂             ⎛        ∂
# ⎢⎢            0                          0              ⎜- r ⋅──(ψ(r, t)) + ⎜ω(r, t)⋅──(ψ(r,
# ⎢⎢                                                      ⎝     ∂t            ⎝        ∂t
# ⎢⎢
# ⎢⎢                                                                    ⎛
# ⎢⎢                                                                    ⎜
# ⎢⎢                                                                    ⎜        ∂
# ⎢⎢            0                          0                            ⎜ω(r, t)⋅──(ψ(r, t)) +
# ⎢⎣                                                                    ⎝        ∂t
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#
#
#
#
#        0                                                                          0
#
#
#
#        0                                                                          0
#
#
#                                                      ⎛                      ∂          ⎞
#                                                      ⎜                      ──(ω(r, t))⎟
#        ∂          ⎞          4⋅ψ(r, t)⎞  -2⋅γ(r, t)  ⎜        ∂             ∂t         ⎟  -2
#  t)) + ──(ω(r, t))⎟⋅ω(r, t)⋅ℯ         ⎟⋅ℯ            ⎜ω(r, t)⋅──(ψ(r, t)) + ───────────⎟⋅ℯ
#        ∂t         ⎠                   ⎠              ⎝        ∂t                 2     ⎠
#
#  ∂          ⎞
#  ──(ω(r, t))⎟
#  ∂t         ⎟  -2⋅γ(r, t) + 4⋅ψ(r, t)                             -2⋅γ(r, t) + 4⋅ψ(r, t) ∂
#  ───────────⎟⋅ℯ                                                  ℯ                      ⋅──(
#       2     ⎠                                                                            ∂t
#
#
#
#
#
#
#
#
#
#                     ⎤  ⎡∂             ∂            ∂             ∂
#                     ⎥  ⎢──(γ(r, t)) - ──(ψ(r, t))  ──(γ(r, t)) - ──(ψ(r, t))
#                     ⎥  ⎢∂r            ∂r           ∂t            ∂t
#                     ⎥  ⎢
#                     ⎥  ⎢∂             ∂            ∂             ∂
#                     ⎥  ⎢──(γ(r, t)) - ──(ψ(r, t))  ──(γ(r, t)) - ──(ψ(r, t))
#                     ⎥  ⎢∂t            ∂t           ∂r            ∂r
#                     ⎥  ⎢
#                     ⎥  ⎢
#                     ⎥  ⎢
# ⋅γ(r, t) + 4⋅ψ(r, t)⎥  ⎢                                                      ⎛ 2 ∂
#                     ⎥  ⎢            0                          0              ⎜r ⋅──(ψ(r, t)
#                     ⎥  ⎢                                                      ⎝   ∂r
#                     ⎥  ⎢
#                     ⎥  ⎢
#                     ⎥  ⎢
#                     ⎥  ⎢
# ψ(r, t))            ⎥  ⎢            0                          0
#                     ⎦  ⎣
#
#
#
#
#
#
#
#
#
#
#                               0
#
#
#
#                               0
#
#
#                                                                               ⎛
#                                                                               ⎜
#         ⎛        ∂             ∂          ⎞          4⋅ψ(r, t)⎞  -2⋅γ(r, t)   ⎜        ∂
# ) - r - ⎜ω(r, t)⋅──(ψ(r, t)) + ──(ω(r, t))⎟⋅ω(r, t)⋅ℯ         ⎟⋅ℯ            -⎜ω(r, t)⋅──(ψ(
#         ⎝        ∂r            ∂r         ⎠                   ⎠               ⎝        ∂r
#
#  ⎛                      ∂          ⎞
#  ⎜                      ──(ω(r, t))⎟
#  ⎜        ∂             ∂r         ⎟  -2⋅γ(r, t) + 4⋅ψ(r, t)                               -
# -⎜ω(r, t)⋅──(ψ(r, t)) + ───────────⎟⋅ℯ                                                   -ℯ
#  ⎝        ∂r                 2     ⎠
#
#
#
#
#
#                                                 ⎡
#                                                 ⎢
#                                                 ⎢
#                                                 ⎢                      0
#                                              ⎤  ⎢
#               0                              ⎥  ⎢
#                                              ⎥  ⎢
#                                              ⎥  ⎢
#                                              ⎥  ⎢
#               0                              ⎥  ⎢
#                                              ⎥  ⎢                      0
#                                              ⎥  ⎢
#          ∂          ⎞                        ⎥  ⎢
#          ──(ω(r, t))⎟                        ⎥  ⎢
#          ∂r         ⎟  -2⋅γ(r, t) + 4⋅ψ(r, t)⎥  ⎢                         4⋅ψ(r, t) ∂
# r, t)) + ───────────⎟⋅ℯ                      ⎥  ⎢                ω(r, t)⋅ℯ         ⋅──(ω(r,
#               2     ⎠                        ⎥  ⎢  ∂                                ∂t
#                                              ⎥  ⎢- ──(ψ(r, t)) + ───────────────────────────
#                                              ⎥  ⎢  ∂t                            2
#                                              ⎥  ⎢                             2⋅r
# 2⋅γ(r, t) + 4⋅ψ(r, t) ∂                      ⎥  ⎢
#                      ⋅──(ψ(r, t))            ⎥  ⎢             4⋅ψ(r, t) ∂
#                       ∂r                     ⎦  ⎢            ℯ         ⋅──(ω(r, t))
#                                                 ⎢                       ∂t
#                                                 ⎢            ──────────────────────
#                                                 ⎢                        2
#                                                 ⎣                     2⋅r
#
#                                                                                     4⋅ψ(r, t
#                                                                            ω(r, t)⋅ℯ
#                                                              ∂
#                              0                             - ──(ψ(r, t)) + ─────────────────
#                                                              ∂t                            2
#                                                                                         2⋅r
#
#                                                                                       4⋅ψ(r,
#                                                                              ω(r, t)⋅ℯ
#                                                            ∂             1
#                              0                           - ──(ψ(r, t)) + ─ + ───────────────
#                                                            ∂r            r
#                                                                                           2⋅
#
#                                   4⋅ψ(r, t) ∂
# t))                      ω(r, t)⋅ℯ         ⋅──(ω(r, t))
#        ∂             1                      ∂r
# ───  - ──(ψ(r, t)) + ─ + ──────────────────────────────                          0
#        ∂r            r                   2
#                                       2⋅r
#
#                     4⋅ψ(r, t) ∂
#                    ℯ         ⋅──(ω(r, t))
#                               ∂r
#                    ──────────────────────                                        0
#                                2
#                             2⋅r
#
# ) ∂               4⋅ψ(r, t) ∂          ⎤  ⎡
#  ⋅──(ω(r, t))    ℯ         ⋅──(ω(r, t))⎥  ⎢
#   ∂t                        ∂t         ⎥  ⎢
# ─────────────    ──────────────────────⎥  ⎢                                  0
#                              2         ⎥  ⎢
#                           2⋅r          ⎥  ⎢
#                                        ⎥  ⎢
#  t) ∂             4⋅ψ(r, t) ∂          ⎥  ⎢
#    ⋅──(ω(r, t))  ℯ         ⋅──(ω(r, t))⎥  ⎢
#     ∂r                      ∂r         ⎥  ⎢
# ───────────────  ──────────────────────⎥  ⎢                                  0
#  2                           2         ⎥  ⎢
# r                         2⋅r          ⎥  ⎢
#                                        ⎥  ⎢
#                                        ⎥  ⎢                        ∂              2        4
#                                        ⎥  ⎢                        ──(ω(r, t))   ω (r, t)⋅ℯ
#                                        ⎥  ⎢          ∂             ∂t
#                            0           ⎥  ⎢2⋅ω(r, t)⋅──(ψ(r, t)) + ─────────── - ───────────
#                                        ⎥  ⎢          ∂t                 2
#                                        ⎥  ⎢
#                                        ⎥  ⎢
#                                        ⎥  ⎢                                   4⋅ψ(r, t) ∂
#                                        ⎥  ⎢                          ω(r, t)⋅ℯ         ⋅──(ω
#                                        ⎥  ⎢            ∂                                ∂t
#                            0           ⎥  ⎢            ──(ψ(r, t)) - ───────────────────────
#                                        ⎥  ⎢            ∂t                            2
#                                        ⎦  ⎣                                       2⋅r
#
#
#
#
#                                                              0
#
#
#
#
#
#
#                                                              0
#
#
#
# ⋅ψ(r, t) ∂                                    ∂                        2        4⋅ψ(r, t) ∂
#         ⋅──(ω(r, t))                          ──(ω(r, t))             ω (r, t)⋅ℯ         ⋅──
#          ∂t                     ∂             ∂r            ω(r, t)                       ∂r
# ────────────────────  2⋅ω(r, t)⋅──(ψ(r, t)) + ─────────── - ─────── - ──────────────────────
#       2                         ∂r                 2           r                       2
#    2⋅r                                                                              2⋅r
#
#                                                               4⋅ψ(r, t) ∂
# (r, t))                                              ω(r, t)⋅ℯ         ⋅──(ω(r, t))
#                                        ∂                                ∂r
# ───────                                ──(ψ(r, t)) - ──────────────────────────────
#                                        ∂r                            2
#                                                                   2⋅r
#
#                                         ∂              2        4⋅ψ(r, t) ∂
#                                         ──(ω(r, t))   ω (r, t)⋅ℯ         ⋅──(ω(r, t))
#                           ∂             ∂t                                ∂t
#                 2⋅ω(r, t)⋅──(ψ(r, t)) + ─────────── - ───────────────────────────────
#                           ∂t                 2                         2
#                                                                     2⋅r
#
#                                    ∂                        2        4⋅ψ(r, t) ∂
#                                    ──(ω(r, t))             ω (r, t)⋅ℯ         ⋅──(ω(r, t))
#                      ∂             ∂r            ω(r, t)                       ∂r
#            2⋅ω(r, t)⋅──(ψ(r, t)) + ─────────── - ─────── - ───────────────────────────────
#                      ∂r                 2           r                       2
#                                                                          2⋅r
#
#
# (ω(r, t))
#
# ─────────                                         0
#
#
#
#
#
#
#                                                   0
#
#
#
#                        4⋅ψ(r, t) ∂          ⎤⎤
#               ω(r, t)⋅ℯ         ⋅──(ω(r, t))⎥⎥
# ∂                                ∂t         ⎥⎥
# ──(ψ(r, t)) - ──────────────────────────────⎥⎥
# ∂t                            2             ⎥⎥
#                            2⋅r              ⎥⎥
#                                             ⎥⎥
#                        4⋅ψ(r, t) ∂          ⎥⎥
#               ω(r, t)⋅ℯ         ⋅──(ω(r, t))⎥⎥
# ∂                                ∂r         ⎥⎥
# ──(ψ(r, t)) - ──────────────────────────────⎥⎥
# ∂r                            2             ⎥⎥
#                            2⋅r              ⎥⎥
#                                             ⎥⎥
#                                             ⎥⎥
#                                             ⎥⎥
#                                             ⎥⎥
#                      0                      ⎥⎥
#                                             ⎥⎥
#                                             ⎥⎥
#                                             ⎥⎥
#                                             ⎥⎥
#                                             ⎥⎥
#                                             ⎥⎥
#                      0                      ⎥⎥
#                                             ⎥⎥
#                                             ⎦⎦

# %%
Ric = RicciTensor.from_metric(metric)
Ric.tensor()
# Out:
# ⎡
# ⎢                                                                               ∂
# ⎢  2              2              2                           2     2            ──(γ(r, t))
# ⎢ ∂              ∂              ∂               ⎛∂          ⎞     ∂             ∂r
# ⎢───(γ(r, t)) - ───(γ(r, t)) - ───(ψ(r, t)) - 2⋅⎜──(ψ(r, t))⎟  + ───(ψ(r, t)) + ───────────
# ⎢  2              2              2              ⎝∂t         ⎠      2                 r
# ⎢∂r             ∂t             ∂r                                ∂t
# ⎢
# ⎢
# ⎢                                                         ∂              4⋅ψ(r, t) ∂
# ⎢                                                         ──(γ(r, t))   ℯ         ⋅──(ω(r, t
# ⎢                               ∂           ∂             ∂t                       ∂r
# ⎢                           - 2⋅──(ψ(r, t))⋅──(ψ(r, t)) + ─────────── - ────────────────────
# ⎢                               ∂r          ∂t                 r                          2
# ⎢                                                                                      2⋅r
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                 0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                 0
# ⎢
# ⎣
#
#                                         2
#   ∂              4⋅ψ(r, t) ⎛∂          ⎞
#   ──(ψ(r, t))   ℯ         ⋅⎜──(ω(r, t))⎟
#   ∂r                       ⎝∂t         ⎠                                   ∂           ∂
# - ─────────── - ─────────────────────────                              - 2⋅──(ψ(r, t))⋅──(ψ(
#        r                      2                                            ∂r          ∂t
#                            2⋅r
#
#
#    ∂
# ))⋅──(ω(r, t))                                 2              2                           2
#    ∂t                                         ∂              ∂               ⎛∂          ⎞
# ──────────────                             - ───(γ(r, t)) + ───(γ(r, t)) - 2⋅⎜──(ψ(r, t))⎟
#                                                2              2              ⎝∂r         ⎠
#                                              ∂r             ∂t
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          ∂              4⋅ψ(r, t) ∂           ∂
#          ──(γ(r, t))   ℯ         ⋅──(ω(r, t))⋅──(ω(r, t))
#          ∂t                       ∂r          ∂t
# r, t)) + ─────────── - ──────────────────────────────────
#               r                          2
#                                       2⋅r
#
#                                                                                     2
#                                 ∂             ∂              4⋅ψ(r, t) ⎛∂          ⎞
#     2              2            ──(γ(r, t))   ──(ψ(r, t))   ℯ         ⋅⎜──(ω(r, t))⎟
#    ∂              ∂             ∂r            ∂r                       ⎝∂r         ⎠
# + ───(ψ(r, t)) - ───(ψ(r, t)) + ─────────── + ─────────── - ─────────────────────────
#     2              2                 r             r                      2
#   ∂r             ∂t                                                    2⋅r
#
#                                                                                        ⎛
#                                                                                        ⎜
#                                                                                        ⎜
#                                                                                        ⎜ 4
#                                                                                        ⎜r ⋅─
#                                                                                        ⎜
#                                                                                        ⎝   ∂
#                  0                                                                     ─────
#
#
#
#
#
#
#
#
#
#
#                  0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2                 2                                                      2
# ∂              4  ∂              3 ∂              2  2        4⋅ψ(r, t)  ∂              2  2
# ──(ψ(r, t)) - r ⋅───(ψ(r, t)) + r ⋅──(ψ(r, t)) - r ⋅ω (r, t)⋅ℯ         ⋅───(ψ(r, t)) + r ⋅ω
#  2                 2               ∂r                                     2
# r                ∂t                                                     ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     2
#         4⋅ψ(r, t)  ∂                2          4⋅ψ(r, t) ∂           ∂              2
# (r, t)⋅ℯ         ⋅───(ψ(r, t)) - 4⋅r ⋅ω(r, t)⋅ℯ         ⋅──(ω(r, t))⋅──(ψ(r, t)) - r ⋅ω(r, t
#                     2                                    ∂r          ∂r
#                   ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                  ⎛                 2                           2
#                  ⎜     2          ∂                2          ∂                2 ∂
#                  ⎜- 2⋅r ⋅ω(r, t)⋅───(ψ(r, t)) + 2⋅r ⋅ω(r, t)⋅───(ψ(r, t)) - 4⋅r ⋅──(ω(r, t))
#                  ⎜                 2                           2                 ∂r
#                  ⎝               ∂r                          ∂t
#                  ───────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                                                                        0
#
#
#
#
#
#
#
#                                                                        0
#
#
#
#
#
#                2
#    4⋅ψ(r, t)  ∂                2          4⋅ψ(r, t) ∂           ∂              2          4⋅
# )⋅ℯ         ⋅───(ω(r, t)) + 4⋅r ⋅ω(r, t)⋅ℯ         ⋅──(ω(r, t))⋅──(ψ(r, t)) + r ⋅ω(r, t)⋅ℯ
#                2                                    ∂t          ∂t
#              ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                         2
#                                                                        r
#
#
#
#                     2                                                2
#  ∂              2  ∂                2 ∂           ∂              2  ∂
# ⋅──(ψ(r, t)) - r ⋅───(ω(r, t)) + 4⋅r ⋅──(ω(r, t))⋅──(ψ(r, t)) + r ⋅───(ω(r, t)) - 2⋅r⋅ω(r, t
#  ∂r                 2                 ∂t          ∂t                 2
#                   ∂r                                               ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                          2
#                                                                       2⋅r
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                   2                              2
#                         2  4⋅ψ(r, t) ⎛∂          ⎞     2  4⋅ψ(r, t) ⎛∂          ⎞
#           2            r ⋅ℯ         ⋅⎜──(ω(r, t))⎟    r ⋅ℯ         ⋅⎜──(ω(r, t))⎟
# ψ(r, t)  ∂                           ⎝∂r         ⎠                  ⎝∂t         ⎠       2
#        ⋅───(ω(r, t)) - ──────────────────────────── + ──────────────────────────── - r⋅ω (r,
#           2                         2                              2
#         ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                                                 2
#   ∂               ∂                      4⋅ψ(r, t) ⎛∂          ⎞             4⋅ψ(r, t) ⎛∂
# )⋅──(ψ(r, t)) + r⋅──(ω(r, t)) + ω(r, t)⋅ℯ         ⋅⎜──(ω(r, t))⎟  - ω(r, t)⋅ℯ         ⋅⎜──(ω
#   ∂r              ∂r                               ⎝∂r         ⎠                       ⎝∂t
#
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                  2        8⋅ψ(r, t) ⎛∂
#                                                                 ω (r, t)⋅ℯ         ⋅⎜──(ω(r,
#      4⋅ψ(r, t) ∂                        4⋅ψ(r, t) ∂                                 ⎝∂r
#  t)⋅ℯ         ⋅──(ψ(r, t)) + r⋅ω(r, t)⋅ℯ         ⋅──(ω(r, t)) + ────────────────────────────
#                ∂r                                 ∂r                            2
#
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#         2⎞
#        ⎞ ⎟  -2⋅γ(r, t) + 4⋅ψ(r, t)
# (r, t))⎟ ⎟⋅ℯ
#        ⎠ ⎟
#          ⎠
# ──────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      2                                    2⎞
#     ⎞     2        8⋅ψ(r, t) ⎛∂          ⎞ ⎟
#  t))⎟    ω (r, t)⋅ℯ         ⋅⎜──(ω(r, t))⎟ ⎟              ⎛                 2
#     ⎠                        ⎝∂t         ⎠ ⎟  -2⋅γ(r, t)  ⎜     2          ∂
# ────── - ──────────────────────────────────⎟⋅ℯ            ⎜- 2⋅r ⋅ω(r, t)⋅───(ψ(r, t)) + 2⋅r
#                          2                 ⎟              ⎜                 2
#                                            ⎠              ⎝               ∂r
# ────────────────────────────────────────────────────────  ──────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             2                                                2
# 2          ∂                2 ∂           ∂              2  ∂                2 ∂           ∂
#  ⋅ω(r, t)⋅───(ψ(r, t)) - 4⋅r ⋅──(ω(r, t))⋅──(ψ(r, t)) - r ⋅───(ω(r, t)) + 4⋅r ⋅──(ω(r, t))⋅─
#             2                 ∂r          ∂r                 2                 ∂t          ∂
#           ∂t                                               ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                               ⎛
#                                               ⎜
#                                               ⎜       2                 2
#                                               ⎜   2  ∂              2  ∂               ∂
#                                               ⎜- r ⋅───(ψ(r, t)) + r ⋅───(ψ(r, t)) - r⋅──(ψ(
#                                               ⎜       2                 2              ∂r
#                                               ⎝     ∂r                ∂t
#                                               ──────────────────────────────────────────────
#
#
#
#
#
#
#
#                     0
#
#
#
#
#
#
#
#                     0
#
#
#
#
#
#                   2
#               2  ∂                         ∂               ∂                      4⋅ψ(r, t)
# ─(ψ(r, t)) + r ⋅───(ω(r, t)) - 2⋅r⋅ω(r, t)⋅──(ψ(r, t)) + r⋅──(ω(r, t)) + ω(r, t)⋅ℯ         ⋅
# t                 2                        ∂r              ∂r
#                 ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#                       2
#                    2⋅r
#
#                                  2                           2⎞
#           4⋅ψ(r, t) ⎛∂          ⎞     4⋅ψ(r, t) ⎛∂          ⎞ ⎟
#          ℯ         ⋅⎜──(ω(r, t))⎟    ℯ         ⋅⎜──(ω(r, t))⎟ ⎟
#                     ⎝∂r         ⎠               ⎝∂t         ⎠ ⎟  -2⋅γ(r, t) + 4⋅ψ(r, t)
# r, t)) + ───────────────────────── - ─────────────────────────⎟⋅ℯ
#                      2                           2            ⎟
#                                                               ⎠
# ───────────────────────────────────────────────────────────────────────────────────────
#                      2
#                     r
#
#                                                                            ⎤
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#              2                                   2⎞                        ⎥
# ⎛∂          ⎞             4⋅ψ(r, t) ⎛∂          ⎞ ⎟  -2⋅γ(r, t) + 4⋅ψ(r, t)⎥
# ⎜──(ω(r, t))⎟  - ω(r, t)⋅ℯ         ⋅⎜──(ω(r, t))⎟ ⎟⋅ℯ                      ⎥
# ⎝∂r         ⎠                       ⎝∂t         ⎠ ⎟                        ⎥
#                                                   ⎠                        ⎥
# ───────────────────────────────────────────────────────────────────────────⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎥
#                                                                            ⎦

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()
# Out:
# ⎡
# ⎢
# ⎢                                                                               ∂
# ⎢  2              2              2                           2     2            ──(γ(r, t))
# ⎢ ∂              ∂              ∂               ⎛∂          ⎞     ∂             ∂r
# ⎢───(γ(r, t)) - ───(γ(r, t)) - ───(ψ(r, t)) - 2⋅⎜──(ψ(r, t))⎟  + ───(ψ(r, t)) + ───────────
# ⎢  2              2              2              ⎝∂t         ⎠      2                 r
# ⎢∂r             ∂t             ∂r                                ∂t
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                      ⎛       2                   2                              2          2
#                      ⎜   2  ∂                2  ∂                2 ⎛∂          ⎞       2  ∂
#   ∂             0.25⋅⎜4⋅r ⋅───(γ(r, t)) - 4⋅r ⋅───(γ(r, t)) + 4⋅r ⋅⎜──(ψ(r, t))⎟  - 4⋅r ⋅───
#   ──(ψ(r, t))        ⎜       2                   2                 ⎝∂r         ⎠           2
#   ∂r                 ⎝     ∂r                  ∂t                                        ∂r
# - ─────────── - ────────────────────────────────────────────────────────────────────────────
#        r
#
#
#
#
#
#
#                                                                   ∂           ∂
#                                                               - 2⋅──(ψ(r, t))⋅──(ψ(r, t)) +
#                                                                   ∂r          ∂t
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                               2          2
#                2 ⎛∂          ⎞       2  ∂                 ∂              4⋅ψ(r, t) ⎛∂
# (ψ(r, t)) - 4⋅r ⋅⎜──(ψ(r, t))⎟  + 4⋅r ⋅───(ψ(r, t)) - 4⋅r⋅──(ψ(r, t)) + ℯ         ⋅⎜──(ω(r,
#                  ⎝∂t         ⎠           2                ∂r                       ⎝∂r
#                                        ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                  2
#                                                 r
#
#
#
# ∂              4⋅ψ(r, t) ∂           ∂
# ──(γ(r, t))   ℯ         ⋅──(ω(r, t))⋅──(ω(r, t))
# ∂t                       ∂r          ∂t
# ─────────── - ──────────────────────────────────
#      r                          2
#                              2⋅r
#
#
#
#
#
#
#
#
#         0
#
#
#
#
#
#
#
#
#
#
#         0
#
#
#
#     2                           2⎞
#    ⎞     4⋅ψ(r, t) ⎛∂          ⎞ ⎟  -2⋅γ(r, t) + 2⋅ψ(r, t)  2⋅γ(r, t)  -2⋅ψ(r, t)
# t))⎟  - ℯ         ⋅⎜──(ω(r, t))⎟ ⎟⋅ℯ                      ⋅ℯ         ⋅ℯ              4⋅ψ(r,
#    ⎠               ⎝∂t         ⎠ ⎟                                                  ℯ
#                                  ⎠
# ───────────────────────────────────────────────────────────────────────────────── - ────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 2
# t) ⎛∂          ⎞
#   ⋅⎜──(ω(r, t))⎟
#    ⎝∂t         ⎠
# ─────────────────
#       2
#    2⋅r
#
#
#
#
#                        2              2                           2     2              2
#                       ∂              ∂               ⎛∂          ⎞     ∂              ∂
#                    - ───(γ(r, t)) + ───(γ(r, t)) - 2⋅⎜──(ψ(r, t))⎟  + ───(ψ(r, t)) - ───(ψ(r
#                        2              2              ⎝∂r         ⎠      2              2
#                      ∂r             ∂t                                ∂r             ∂t
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                      ∂
#                                                                                  - 2⋅──(ψ(r,
#                                                                                      ∂r
#
#
#                                          ⎛       2                   2
#                                          ⎜   2  ∂                2  ∂                2 ⎛∂
#         ∂             ∂             0.25⋅⎜4⋅r ⋅───(γ(r, t)) - 4⋅r ⋅───(γ(r, t)) + 4⋅r ⋅⎜──(ψ
#         ──(γ(r, t))   ──(ψ(r, t))        ⎜       2                   2                 ⎝∂r
#         ∂r            ∂r                 ⎝     ∂r                  ∂t
# , t)) + ─────────── + ─────────── + ────────────────────────────────────────────────────────
#              r             r
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                    ∂              4⋅ψ(r, t) ∂           ∂
#                    ──(γ(r, t))   ℯ         ⋅──(ω(r, t))⋅──(ω(r, t))
#      ∂             ∂t                       ∂r          ∂t
#  t))⋅──(ψ(r, t)) + ─────────── - ──────────────────────────────────
#      ∂t                 r                          2
#                                                 2⋅r
#
#         2          2                              2          2
#        ⎞       2  ∂                2 ⎛∂          ⎞       2  ∂                 ∂
# (r, t))⎟  - 4⋅r ⋅───(ψ(r, t)) - 4⋅r ⋅⎜──(ψ(r, t))⎟  + 4⋅r ⋅───(ψ(r, t)) - 4⋅r⋅──(ψ(r, t)) +
#        ⎠           2                 ⎝∂t         ⎠           2                ∂r
#                  ∂r                                        ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                      2
#                                                                     r
#
#
#
#
#
#
#
#
#                            0
#
#
#
#
#
#
#
#
#
#
#                            0
#
#
#
#
#
#
#
#
#
#
#
#
#                         2                           2⎞
#  4⋅ψ(r, t) ⎛∂          ⎞     4⋅ψ(r, t) ⎛∂          ⎞ ⎟  -2⋅γ(r, t) + 2⋅ψ(r, t)  2⋅γ(r, t)  -
# ℯ         ⋅⎜──(ω(r, t))⎟  - ℯ         ⋅⎜──(ω(r, t))⎟ ⎟⋅ℯ                      ⋅ℯ         ⋅ℯ
#            ⎝∂r         ⎠               ⎝∂t         ⎠ ⎟
#                                                      ⎠
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2⋅ψ(r, t)                           2
#              4⋅ψ(r, t) ⎛∂          ⎞
#             ℯ         ⋅⎜──(ω(r, t))⎟
#                        ⎝∂r         ⎠
# ───────── - ─────────────────────────
#                           2
#                        2⋅r
#
#
#
#                                                                                           ⎛
#                                          ⎛       2  -2⋅ψ(r, t)        2        2⋅ψ(r, t)⎞ ⎜
#                                          ⎝- 0.5⋅r ⋅ℯ           - 0.5⋅ω (r, t)⋅ℯ         ⎠⋅⎜4
#                                                                                           ⎜
#                                                                                           ⎝
#                                        - ───────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       2                   2                              2          2
#   2  ∂                2  ∂                2 ⎛∂          ⎞       2  ∂                2 ⎛∂
# ⋅r ⋅───(γ(r, t)) - 4⋅r ⋅───(γ(r, t)) + 4⋅r ⋅⎜──(ψ(r, t))⎟  - 4⋅r ⋅───(ψ(r, t)) - 4⋅r ⋅⎜──(ψ(
#       2                   2                 ⎝∂r         ⎠           2                 ⎝∂t
#     ∂r                  ∂t                                        ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                      2
#                                                                                   2⋅r
#
#
#
#                                                                                ⎛       2
#                                                                                ⎜   2  ∂
#                                                                           0.25⋅⎜4⋅r ⋅───(γ(r
#                                                                                ⎜       2
#                                                                                ⎝     ∂r
#                                                                           ──────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        2          2                                                      2
#       ⎞       2  ∂                 ∂              4⋅ψ(r, t) ⎛∂          ⎞     4⋅ψ(r, t) ⎛∂
# r, t))⎟  + 4⋅r ⋅───(ψ(r, t)) - 4⋅r⋅──(ψ(r, t)) + ℯ         ⋅⎜──(ω(r, t))⎟  - ℯ         ⋅⎜──(
#       ⎠           2                ∂r                       ⎝∂r         ⎠               ⎝∂t
#                 ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                2                              2          2                              2
#            2  ∂                2 ⎛∂          ⎞       2  ∂                2 ⎛∂          ⎞
# , t)) - 4⋅r ⋅───(γ(r, t)) + 4⋅r ⋅⎜──(ψ(r, t))⎟  - 4⋅r ⋅───(ψ(r, t)) - 4⋅r ⋅⎜──(ψ(r, t))⎟  +
#                2                 ⎝∂r         ⎠           2                 ⎝∂t         ⎠
#              ∂t                                        ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                       ⎛
#                                       ⎜
#          2⎞                           ⎜     2                 2
#         ⎞ ⎟  -2⋅γ(r, t) + 2⋅ψ(r, t)   ⎜ 4  ∂              4  ∂              3 ∂
# ω(r, t))⎟ ⎟⋅ℯ                         ⎜r ⋅───(ψ(r, t)) - r ⋅───(ψ(r, t)) + r ⋅──(ψ(r, t)) -
#         ⎠ ⎟                           ⎜     2                 2               ∂r
#           ⎠                           ⎝   ∂r                ∂t
# ─────────────────────────────────── + ──────────────────────────────────────────────────────
#
#
#
#
#
#        2                                                      2                           2⎞
#    2  ∂                 ∂              4⋅ψ(r, t) ⎛∂          ⎞     4⋅ψ(r, t) ⎛∂          ⎞ ⎟
# 4⋅r ⋅───(ψ(r, t)) - 4⋅r⋅──(ψ(r, t)) + ℯ         ⋅⎜──(ω(r, t))⎟  - ℯ         ⋅⎜──(ω(r, t))⎟ ⎟
#        2                ∂r                       ⎝∂r         ⎠               ⎝∂t         ⎠ ⎟
#      ∂t                                                                                    ⎠
# ────────────────────────────────────────────────────────────────────────────────────────────
#              2
#             r
#
#
#
#
#
#
#                                                                     0
#
#
#
#
#
#
#
#
#                                                                     0
#
#
#
#
#
#                          2                                     2
#  2  2        4⋅ψ(r, t)  ∂              2  2        4⋅ψ(r, t)  ∂                2          4⋅
# r ⋅ω (r, t)⋅ℯ         ⋅───(ψ(r, t)) + r ⋅ω (r, t)⋅ℯ         ⋅───(ψ(r, t)) - 4⋅r ⋅ω(r, t)⋅ℯ
#                          2                                     2
#                        ∂r                                    ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                               ⎛                 2
#           -2⋅γ(r, t) + 2⋅ψ(r, t)  2⋅ψ(r, t)   ⎜     2          ∂                2          ∂
# ⋅ω(r, t)⋅ℯ                      ⋅ℯ            ⎜- 2⋅r ⋅ω(r, t)⋅───(ψ(r, t)) + 2⋅r ⋅ω(r, t)⋅──
#                                               ⎜                 2
#                                               ⎝               ∂r                          ∂t
# ─────────────────────────────────────────── + ──────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
# ...
#           ⎝∂t         ⎠           2                ∂r                       ⎝∂r         ⎠
#                                 ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                         2
#                                        r
#
#  ⎛                                                                              2
#  ⎜                                                       4⋅ψ(r, t) ⎛∂          ⎞     4⋅ψ(r,
#  ⎜       2                 2                            ℯ         ⋅⎜──(ω(r, t))⎟    ℯ
#  ⎜   2  ∂              2  ∂               ∂                        ⎝∂r         ⎠
#  ⎜- r ⋅───(ψ(r, t)) + r ⋅───(ψ(r, t)) - r⋅──(ψ(r, t)) + ───────────────────────── - ────────
#  ⎜       2                 2              ∂r                        2
#  ⎝     ∂r                ∂t
#  ───────────────────────────────────────────────────────────────────────────────────────────
#                                                                     2
#                                                                    r
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                          2⎞                                              ⎛                 2
#   4⋅ψ(r, t) ⎛∂          ⎞ ⎟          -2⋅γ(r, t) + 2⋅ψ(r, t)  2⋅ψ(r, t)   ⎜     2          ∂
#  ℯ         ⋅⎜──(ω(r, t))⎟ ⎟⋅ω(r, t)⋅ℯ                      ⋅ℯ            ⎜- 2⋅r ⋅ω(r, t)⋅───
#             ⎝∂t         ⎠ ⎟                                              ⎜                 2
#                           ⎠                                              ⎝               ∂r
# ────────────────────────────────────────────────────────────────────── + ───────────────────
#
#
#
#                 2⎞
# t) ⎛∂          ⎞ ⎟
#   ⋅⎜──(ω(r, t))⎟ ⎟                                ⎛       2                   2
#    ⎝∂t         ⎠ ⎟  -2⋅γ(r, t) + 4⋅ψ(r, t)        ⎜   2  ∂                2  ∂
# ─────────────────⎟⋅ℯ                         0.25⋅⎜4⋅r ⋅───(γ(r, t)) - 4⋅r ⋅───(γ(r, t)) + 4
#     2            ⎟                                ⎜       2                   2
#                  ⎠                                ⎝     ∂r                  ∂t
# ────────────────────────────────────────── + ───────────────────────────────────────────────
#
#
#
#
#
#
#
#
#    0
#
#
#
#
#
#
#
#
#    0
#
#
#
#
#
#                            2                                                2
#                2          ∂                2 ∂           ∂              2  ∂
# (ψ(r, t)) + 2⋅r ⋅ω(r, t)⋅───(ψ(r, t)) - 4⋅r ⋅──(ω(r, t))⋅──(ψ(r, t)) - r ⋅───(ω(r, t)) + 4⋅r
#                            2                 ∂r          ∂r                 2
#                          ∂t                                               ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                  2          2                              2          2
#   2 ⎛∂          ⎞       2  ∂                2 ⎛∂          ⎞       2  ∂                 ∂
# ⋅r ⋅⎜──(ψ(r, t))⎟  - 4⋅r ⋅───(ψ(r, t)) - 4⋅r ⋅⎜──(ψ(r, t))⎟  + 4⋅r ⋅───(ψ(r, t)) - 4⋅r⋅──(ψ(
#     ⎝∂r         ⎠           2                 ⎝∂t         ⎠           2                ∂r
#                           ∂r                                        ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                                                         2
#                                                                        r
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                  2
# 2 ∂           ∂              2  ∂                         ∂               ∂
#  ⋅──(ω(r, t))⋅──(ψ(r, t)) + r ⋅───(ω(r, t)) - 2⋅r⋅ω(r, t)⋅──(ψ(r, t)) + r⋅──(ω(r, t)) + ω(r,
#   ∂t          ∂t                 2                        ∂r              ∂r
#                                ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#                                      2
#                                   2⋅r
#
#
#
#                                  2                           2⎞
#           4⋅ψ(r, t) ⎛∂          ⎞     4⋅ψ(r, t) ⎛∂          ⎞ ⎟  -2⋅γ(r, t) + 2⋅ψ(r, t)  2⋅ψ
# r, t)) + ℯ         ⋅⎜──(ω(r, t))⎟  - ℯ         ⋅⎜──(ω(r, t))⎟ ⎟⋅ℯ                      ⋅ℯ
#                     ⎝∂r         ⎠               ⎝∂t         ⎠ ⎟
#                                                               ⎠
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                                           ⎤
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                             2                                   2⎞                        ⎥
#      4⋅ψ(r, t) ⎛∂          ⎞             4⋅ψ(r, t) ⎛∂          ⎞ ⎟  -2⋅γ(r, t) + 4⋅ψ(r, t)⎥
#  t)⋅ℯ         ⋅⎜──(ω(r, t))⎟  - ω(r, t)⋅ℯ         ⋅⎜──(ω(r, t))⎟ ⎟⋅ℯ                      ⎥
#                ⎝∂r         ⎠                       ⎝∂t         ⎠ ⎟                        ⎥
#                                                                  ⎠                        ⎥
# ──────────────────────────────────────────────────────────────────────────────────────────⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
# (r, t)                                                                                    ⎥
#                                                                                           ⎥
#                                                                                           ⎥
#                                                                                           ⎥
# ──────                                                                                    ⎥
#                                                                                           ⎥
#                                                                                           ⎦

# %%
R = RicciScalar.from_riccitensor(Ric)
R.simplify()
R.expr
# Out:
# ⎛       2                   2                              2          2
# ⎜   2  ∂                2  ∂                2 ⎛∂          ⎞       2  ∂                2 ⎛∂
# ⎜4⋅r ⋅───(γ(r, t)) - 4⋅r ⋅───(γ(r, t)) + 4⋅r ⋅⎜──(ψ(r, t))⎟  - 4⋅r ⋅───(ψ(r, t)) - 4⋅r ⋅⎜──(
# ⎜       2                   2                 ⎝∂r         ⎠           2                 ⎝∂t
# ⎝     ∂r                  ∂t                                        ∂r
# ────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#          2          2                                                      2
#         ⎞       2  ∂                 ∂              4⋅ψ(r, t) ⎛∂          ⎞     4⋅ψ(r, t) ⎛∂
# ψ(r, t))⎟  + 4⋅r ⋅───(ψ(r, t)) - 4⋅r⋅──(ψ(r, t)) + ℯ         ⋅⎜──(ω(r, t))⎟  - ℯ         ⋅⎜─
#         ⎠           2                ∂r                       ⎝∂r         ⎠               ⎝∂
#                   ∂t
# ────────────────────────────────────────────────────────────────────────────────────────────
#                     2
#                  2⋅r
#
#            2⎞
#           ⎞ ⎟  -2⋅γ(r, t) + 2⋅ψ(r, t)
# ─(ω(r, t))⎟ ⎟⋅ℯ
# t         ⎠ ⎟
#             ⎠
# ─────────────────────────────────────

# %%
rm1 = RiemannCurvatureTensor.from_christoffels(ch)
rm1.tensor()

# %%
weyl = WeylTensor.from_metric(metric)
weyl.tensor()
