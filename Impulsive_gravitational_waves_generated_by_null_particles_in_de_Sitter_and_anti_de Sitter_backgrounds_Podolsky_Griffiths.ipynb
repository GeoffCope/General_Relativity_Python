# %% [markdown]
# # Impulsive gravitational waves generated by null particles in de Sitter and anti–de Sitter backgrounds Podolsky Griffiths
# ##  Geoff Cope
# ##  Univeristy of Utah
# ##  𐐏𐐭𐑌𐐲𐑂𐐲𐑉𐑅𐐮𐐻𐐨 𐐲𐑂 𐐏𐐭𐐻𐐫
# ##  December 22, 2021

# %%
from sympy import init_session
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.9 (Python 3.8.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
Z_0,Z_1,Z_2,Z_3,Z_4 = symbols( 'Z_0 Z_1 Z_2 Z_3 Z_4' )

# %%
t,r,theta,phi,m,a = symbols('t r theta phi m a')

# %%
equation2pt2 = Eq( Z_0**2 - Z_1**2 -Z_2**2 -Z_3**2 -Z_4**2 , - a**2 )
equation2pt2
# Out:
#   2     2     2     2     2     2
# Z₀  - Z₁  - Z₂  - Z₃  - Z₄  = -a

# %%
equation2pt4a = Eq( Z_0 , (a**2-r**2)**Rational(1,2) * sinh(t/a) ) 
equation2pt4a
# Out:
#         _________
#        ╱  2    2      ⎛t⎞
# Z₀ = ╲╱  a  - r  ⋅sinh⎜─⎟
#                       ⎝a⎠

# %%
equation2pt4b = Eq( Z_4 , (a**2-r**2)**Rational(1,2) * cosh(t/a) ) 
equation2pt4b
# Out:
#         _________
#        ╱  2    2      ⎛t⎞
# Z₄ = ╲╱  a  - r  ⋅cosh⎜─⎟
#                       ⎝a⎠

# %%
equation2pt4c = Eq(Z_1, r * cos(theta))
equation2pt4c
# Out:
# Z₁ = r⋅cos(θ)

# %%
equation2pt4d = Eq(Z_2, r * sin(theta) * cos(phi))
equation2pt4d
# Out:
# Z₂ = r⋅sin(θ)⋅cos(φ)

# %%
equation2pt4e = Eq(Z_3, r * sin(theta) * sin(phi))
equation2pt4e
# Out:
# Z₃ = r⋅sin(φ)⋅sin(θ)

# %%
equation2pt2.subs(equation2pt4a.lhs,equation2pt4a.rhs)
# Out:
#     2     2     2     2   ⎛ 2    2⎞     2⎛t⎞     2
# - Z₁  - Z₂  - Z₃  - Z₄  + ⎝a  - r ⎠⋅sinh ⎜─⎟ = -a
#                                          ⎝a⎠

# %%
equation2pt2.subs(equation2pt4a.lhs,equation2pt4a.rhs).subs(equation2pt4b.lhs,equation2pt4b.rhs)
# Out:
#     2     2     2   ⎛ 2    2⎞     2⎛t⎞   ⎛ 2    2⎞     2⎛t⎞     2
# - Z₁  - Z₂  - Z₃  + ⎝a  - r ⎠⋅sinh ⎜─⎟ - ⎝a  - r ⎠⋅cosh ⎜─⎟ = -a
#                                    ⎝a⎠                  ⎝a⎠

# %%
equation2pt2.subs(equation2pt4a.lhs,equation2pt4a.rhs).subs(equation2pt4b.lhs,equation2pt4b.rhs).subs(equation2pt4c.lhs,equation2pt4c.rhs)
# Out:
#     2     2    2    2      ⎛ 2    2⎞     2⎛t⎞   ⎛ 2    2⎞     2⎛t⎞     2
# - Z₂  - Z₃  - r ⋅cos (θ) + ⎝a  - r ⎠⋅sinh ⎜─⎟ - ⎝a  - r ⎠⋅cosh ⎜─⎟ = -a
#                                           ⎝a⎠                  ⎝a⎠

# %%
equation2pt2.subs(equation2pt4a.lhs,equation2pt4a.rhs).subs(equation2pt4b.lhs,equation2pt4b.rhs).subs(equation2pt4c.lhs,equation2pt4c.rhs).subs(equation2pt4d.lhs,equation2pt4d.rhs)
# Out:
#     2    2    2       2       2    2      ⎛ 2    2⎞     2⎛t⎞   ⎛ 2    2⎞     2⎛t⎞     2
# - Z₃  - r ⋅sin (θ)⋅cos (φ) - r ⋅cos (θ) + ⎝a  - r ⎠⋅sinh ⎜─⎟ - ⎝a  - r ⎠⋅cosh ⎜─⎟ = -a
#                                                          ⎝a⎠                  ⎝a⎠

# %%
equation2pt2.subs(equation2pt4a.lhs,equation2pt4a.rhs).subs(equation2pt4b.lhs,equation2pt4b.rhs).subs(equation2pt4c.lhs,equation2pt4c.rhs).subs(equation2pt4d.lhs,equation2pt4d.rhs).subs(equation2pt4e.lhs,equation2pt4e.rhs)
# Out:
#    2    2       2       2    2       2       2    2      ⎛ 2    2⎞     2⎛t⎞   ⎛ 2    2⎞
# - r ⋅sin (φ)⋅sin (θ) - r ⋅sin (θ)⋅cos (φ) - r ⋅cos (θ) + ⎝a  - r ⎠⋅sinh ⎜─⎟ - ⎝a  - r ⎠⋅cosh
#                                                                         ⎝a⎠
#
# 2⎛t⎞     2
#  ⎜─⎟ = -a
#  ⎝a⎠

# %%
equation2pt2.subs(equation2pt4a.lhs,equation2pt4a.rhs).subs(equation2pt4b.lhs,equation2pt4b.rhs).subs(equation2pt4c.lhs,equation2pt4c.rhs).subs(equation2pt4d.lhs,equation2pt4d.rhs).subs(equation2pt4e.lhs,equation2pt4e.rhs).simplify()
# Out:
# True
